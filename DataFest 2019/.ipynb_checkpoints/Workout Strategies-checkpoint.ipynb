# %%
import pandas as pd
import matplotlib.pyplot as plt

ratios = pd.read_csv('C:\\Users\\Federico Nada\\Desktop\\DataFest/Data for DataFest 2019/rpe.csv')

# %%
import os
print(os.listdir('C:\\Users\\Federico Nada\\Desktop\\DataFest/Notebooks'))
# Out:
# ['.ipynb_checkpoints', 'Exploratory Analysis.ipynb', 'Standardize Values.ipynb', 'train.csv', 'train2.csv', 'Untitled.ipynb', 'Workout Strategies.ipynb']

# %%
ratios['Date'] =  pd.to_datetime(ratios['Date'])
ratios.set_index('Date', inplace=True)
ratios.sort_values('Date', inplace = True)

# %%
ratios['AcuteChronicRatio'].isna().sum()
# Out:
# 4511

# %%
import datetime as datetime
enddates = []
enddates.append('11/29/2017')
enddates.append('01/25/2018')
enddates.append('04/12/2018')
enddates.append('05/11/2018')
enddates.append('06/08/2018')
enddates.append('07/20/2018')
enddates = [datetime.datetime.strptime(x, '%m/%d/%Y') for x in enddates]

# %%
startdates = []
startdates.append('10/15/2017')
startdates.append('12/02/2017')
startdates.append('01/29/2018')
startdates.append('04/23/2018')
startdates.append('05/14/2018')
startdates.append('06/11/2018')
startdates = [datetime.datetime.strptime(x, '%m/%d/%Y') for x in startdates]

# %%
dubai =  ratios.loc[(ratios.index > startdates[0]) & (ratios.index < enddates[0])][['PlayerID' ,'AcuteChronicRatio']]
sydney =  ratios.loc[(ratios.index > startdates[1]) & (ratios.index < enddates[1])][['PlayerID' ,'AcuteChronicRatio']]
commonwealth =  ratios.loc[(ratios.index > startdates[2]) & (ratios.index < enddates[2])][['PlayerID' ,'AcuteChronicRatio']]
langford =  ratios.loc[(ratios.index > startdates[3]) & (ratios.index < enddates[3])][['PlayerID' ,'AcuteChronicRatio']]
paris =  ratios.loc[(ratios.index > startdates[4]) & (ratios.index < enddates[4])][['PlayerID' ,'AcuteChronicRatio']]
world =  ratios.loc[(ratios.index > startdates[5]) & (ratios.index < enddates[5])][['PlayerID' ,'AcuteChronicRatio']]

# %%
counter = 0

dubai_d = {}
for x in range(1, 18):
    dubai_d["dubai{0}".format(x)]= dubai[dubai['PlayerID'] == x].groupby(dubai[dubai['PlayerID'] == x].index).first()['AcuteChronicRatio'].values
    counter += len(dubai[dubai['PlayerID'] == x].groupby(dubai[dubai['PlayerID'] == x].index).first()['AcuteChronicRatio'])
sydney_d = {}
for x in range(1, 18):
    sydney_d["sydney{0}".format(x)]= sydney[sydney['PlayerID'] == x].groupby(sydney[sydney['PlayerID'] == x].index).first()['AcuteChronicRatio'].values
    counter += len(sydney[sydney['PlayerID'] == x].groupby(sydney[sydney['PlayerID'] == x].index).first()['AcuteChronicRatio'])
commonwealth_d = {}
for x in range(1, 18):
    commonwealth_d["commonwealth{0}".format(x)]= commonwealth[commonwealth['PlayerID'] == x].groupby(commonwealth[commonwealth['PlayerID'] == x].index).first()['AcuteChronicRatio'].values
    counter += len(commonwealth[commonwealth['PlayerID'] == x].groupby(commonwealth[commonwealth['PlayerID'] == x].index).first()['AcuteChronicRatio'])
langford_d = {}
for x in range(1, 18):
    langford_d["langford{0}".format(x)]= langford[langford['PlayerID'] == x].groupby(langford[langford['PlayerID'] == x].index).first()['AcuteChronicRatio'].values
    counter += len(langford[langford['PlayerID'] == x].groupby(langford[langford['PlayerID'] == x].index).first()['AcuteChronicRatio'])
paris_d = {}
for x in range(1, 18):
    paris_d["paris{0}".format(x)]= paris[paris['PlayerID'] == x].groupby(paris[paris['PlayerID'] == x].index).first()['AcuteChronicRatio'].values
    counter += len(paris[paris['PlayerID'] == x].groupby(paris[paris['PlayerID'] == x].index).first()['AcuteChronicRatio'])
world_d = {}
for x in range(1, 18):
    world_d["world{0}".format(x)]= world[world['PlayerID'] == x].groupby(world[world['PlayerID'] == x].index).first()['AcuteChronicRatio'].values
    counter += len(world[world['PlayerID'] == x].groupby(world[world['PlayerID'] == x].index).first()['AcuteChronicRatio'])
print(counter)
# Out:
# 3007

# %%
data = {**dubai_d, **sydney_d, **commonwealth_d, **langford_d, **paris_d, **world_d}

# %%
train = pd.DataFrame.from_dict(data, orient='index')

# %%
train.values
# Out:
# array([[0.68, 0.62, 0.42, ...,  nan,  nan,  nan],
#        [0.55, 0.42, 0.44, ...,  nan,  nan,  nan],
#        [0.92, 1.09, 1.02, ...,  nan,  nan,  nan],
#        ...,
#        [0.46, 0.46, 1.27, ...,  nan,  nan,  nan],
#        [0.46, 0.38, 0.47, ...,  nan,  nan,  nan],
#        [1.53, 1.14, 1.49, ...,  nan,  nan,  nan]])

# %%
train = train.transpose()

# %%
train['dubai1'].dropna().groupby(pd.cut(train['dubai1'].dropna().index, 10)).max().plot()
train['dubai1'].dropna().groupby(pd.cut(train['dubai1'].dropna().index, 10)).min().plot()
train['sydney1'].dropna().groupby(pd.cut(train['sydney1'].dropna().index, 10)).min().plot()
train['langford15'].dropna().groupby(pd.cut(train['langford15'].dropna().index, 10)).max().interpolate().plot()
train['langford4'].dropna().groupby(pd.cut(train['langford4'].dropna().index, 10)).max().interpolate().plot()
plt.show()

# %%
train_array = []
bins = 10
for i in range(1,17):
    train_array.append(train['dubai{}'.format(i)].dropna().groupby(pd.cut(train['dubai{}'.format(i)].dropna().index, bins)).max().values)
for i in range(1,17):
    train_array.append(train['sydney{}'.format(i)].dropna().groupby(pd.cut(train['sydney{}'.format(i)].dropna().index, bins)).max().values)
for i in range(1,17):
    train_array.append(train['commonwealth{}'.format(i)].dropna().groupby(pd.cut(train['commonwealth{}'.format(i)].dropna().index, bins)).max().values)
#for i in range(1,17):
#    train_array.append(train['langford{}'.format(i)].dropna().groupby(pd.cut(train['langford{}'.format(i)].dropna().index, bins)).max().values)
#for i in range(1,17):
#    train_array.append(train['paris{}'.format(i)].dropna().groupby(pd.cut(train['paris{}'.format(i)].dropna().index, bins)).max().values)
#for i in range(1,17):
#    train_array.append(train['world{}'.format(i)].dropna().groupby(pd.cut(train['world{}'.format(i)].dropna().index, bins)).max().values)

# %%
ml = pd.DataFrame(train_array)

# %%
ml.to_csv('train.csv')

# %%
data
# Out:
# {'dubai1': array([0.68, 0.62, 0.42, 0.07, 0.07,  nan, 0.01, 0.01, 0.01, 0.05, 0.05,
#         0.05, 0.04, 0.12, 0.23, 0.21, 0.87, 1.19, 1.19, 2.  , 2.24, 1.82,
#         2.02, 2.2 , 2.2 , 1.32, 1.21, 1.38, 0.9 , 0.92, 1.08, 1.08, 0.81,
#         0.96, 1.17, 0.85, 1.  , 1.2 , 1.2 , 0.97, 1.17]),
#  'dubai2': array([0.55, 0.42, 0.44, 0.49, 0.54, 0.67, 0.43, 0.44, 0.51, 0.56, 0.81,
#         0.7 , 0.57, 0.64, 1.01, 0.44, 0.44, 1.02, 0.7 , 1.34, 1.88, 1.88,
#         1.42, 1.68, 1.83, 1.66, 1.18, 1.48, 1.51, 1.18, 1.06, 1.15, 0.92,
#         0.55, 0.66, 0.49, 0.43, 0.34]),
#  'dubai3': array([0.92, 1.09, 1.02, 1.27, 1.13, 1.17, 0.94, 0.71, 0.79, 0.58, 0.66,
#         0.66, 0.67, 0.59, 0.57, 0.68, 0.57, 0.8 , 0.91, 0.91, 0.77, 1.25,
#         1.56, 1.59, 1.85, 2.4 , 2.4 , 1.92, 1.96, 1.68, 1.1 , 1.42, 1.42,
#         1.09, 1.04, 1.06, 0.89, 0.47, 0.47, 0.53, 0.46, 0.49, 0.41]),
#  'dubai4': array([0.55, 0.41, 0.48, 0.74, 1.11, 1.18, 1.02, 0.87, 0.53, 0.49, 0.59,
# ...

# %%
#INTERPOLATE BEFORE

data_array = []
bins = 10

for i in range(1,18):
    data_array.append(pd.Series(data['dubai{}'.format(i)]).interpolate().groupby(pd.cut(pd.Series(data['dubai{}'.format(i)]).index, bins)).max().values)
for i in range(1,18):
    data_array.append(pd.Series(data['sydney{}'.format(i)]).interpolate().groupby(pd.cut(pd.Series(data['sydney{}'.format(i)]).index, bins)).max().values)
for i in range(1,18):
    data_array.append(pd.Series(data['commonwealth{}'.format(i)]).interpolate().groupby(pd.cut(pd.Series(data['commonwealth{}'.format(i)]).index, bins)).max().values)
for i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):
    data_array.append(pd.Series(data['langford{}'.format(i)]).interpolate().groupby(pd.cut(pd.Series(data['langford{}'.format(i)]).index, bins)).max().values)
for i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):
    data_array.append(pd.Series(data['paris{}'.format(i)]).interpolate().groupby(pd.cut(pd.Series(data['paris{}'.format(i)]).index, bins)).max().values)
for i in (1,2,3,4,5,6,7,8,10,11,13,14,15,16,17):
    data_array.append(pd.Series(data['world{}'.format(i)]).interpolate().groupby(pd.cut(pd.Series(data['world{}'.format(i)]).index, bins)).max().values)

# %%
'''#INTERPOLATE AFTER
for i in range(1,18):
    data_array.append(pd.Series(data['dubai{}'.format(i)]).groupby(pd.cut(pd.Series(data['dubai{}'.format(i)]).index, bins)).max().interpolate().values)
for i in range(1,18):
    data_array.append(pd.Series(data['sydney{}'.format(i)]).groupby(pd.cut(pd.Series(data['sydney{}'.format(i)]).index, bins)).max().interpolate().values)
for i in range(1,18):
    data_array.append(pd.Series(data['commonwealth{}'.format(i)]).groupby(pd.cut(pd.Series(data['commonwealth{}'.format(i)]).index, bins)).max().interpolate().values)
for i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):
    data_array.append(pd.Series(data['langford{}'.format(i)]).groupby(pd.cut(pd.Series(data['langford{}'.format(i)]).index, bins)).max().interpolate().values)
for i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):
    data_array.append(pd.Series(data['paris{}'.format(i)]).groupby(pd.cut(pd.Series(data['paris{}'.format(i)]).index, bins)).max().interpolate().values)
for i in (1,2,3,4,5,6,7,8,10,11,13,14,15,16,17):
    data_array.append(pd.Series(data['world{}'.format(i)]).groupby(pd.cut(pd.Series(data['world{}'.format(i)]).index, bins)).max().interpolate().values)'''
# Out:
# "#INTERPOLATE AFTER\nfor i in range(1,18):\n    data_array.append(pd.Series(data['dubai{}'.format(i)]).groupby(pd.cut(pd.Series(data['dubai{}'.format(i)]).index, bins)).max().interpolate().values)\nfor i in range(1,18):\n    data_array.append(pd.Series(data['sydney{}'.format(i)]).groupby(pd.cut(pd.Series(data['sydney{}'.format(i)]).index, bins)).max().interpolate().values)\nfor i in range(1,18):\n    data_array.append(pd.Series(data['commonwealth{}'.format(i)]).groupby(pd.cut(pd.Series(data['commonwealth{}'.format(i)]).index, bins)).max().interpolate().values)\nfor i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):\n    data_array.append(pd.Series(data['langford{}'.format(i)]).groupby(pd.cut(pd.Series(data['langford{}'.format(i)]).index, bins)).max().interpolate().values)\nfor i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):\n    data_array.append(pd.Series(data['paris{}'.format(i)]).groupby(pd.cut(pd.Series(data['paris{}'.format(i)]).index, bins)).max().interpolate().values)\nfor i in (
# ...

# %%
'''#INTERPOLATE AFTER
for i in range(1,18):
    data_array.append(pd.Series(data['dubai{}'.format(i)]).groupby(pd.cut(pd.Series(data['dubai{}'.format(i)]).index, bins)).mean().interpolate().values)
for i in range(1,18):
    data_array.append(pd.Series(data['sydney{}'.format(i)]).groupby(pd.cut(pd.Series(data['sydney{}'.format(i)]).index, bins)).mean().interpolate().values)
for i in range(1,18):
    data_array.append(pd.Series(data['commonwealth{}'.format(i)]).groupby(pd.cut(pd.Series(data['commonwealth{}'.format(i)]).index, bins)).mean().interpolate().values)
for i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):
    data_array.append(pd.Series(data['langford{}'.format(i)]).groupby(pd.cut(pd.Series(data['langford{}'.format(i)]).index, bins)).mean().interpolate().values)
for i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):
    data_array.append(pd.Series(data['paris{}'.format(i)]).groupby(pd.cut(pd.Series(data['paris{}'.format(i)]).index, bins)).mean().interpolate().values)
for i in (1,2,3,4,5,6,7,8,10,11,13,14,15,16,17):
    data_array.append(pd.Series(data['world{}'.format(i)]).groupby(pd.cut(pd.Series(data['world{}'.format(i)]).index, bins)).mean().interpolate().values)'''
# Out:
# "#INTERPOLATE AFTER\nfor i in range(1,18):\n    data_array.append(pd.Series(data['dubai{}'.format(i)]).groupby(pd.cut(pd.Series(data['dubai{}'.format(i)]).index, bins)).mean().interpolate().values)\nfor i in range(1,18):\n    data_array.append(pd.Series(data['sydney{}'.format(i)]).groupby(pd.cut(pd.Series(data['sydney{}'.format(i)]).index, bins)).mean().interpolate().values)\nfor i in range(1,18):\n    data_array.append(pd.Series(data['commonwealth{}'.format(i)]).groupby(pd.cut(pd.Series(data['commonwealth{}'.format(i)]).index, bins)).mean().interpolate().values)\nfor i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):\n    data_array.append(pd.Series(data['langford{}'.format(i)]).groupby(pd.cut(pd.Series(data['langford{}'.format(i)]).index, bins)).mean().interpolate().values)\nfor i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):\n    data_array.append(pd.Series(data['paris{}'.format(i)]).groupby(pd.cut(pd.Series(data['paris{}'.format(i)]).index, bins)).mean().interpolate().values)\nfor i
# ...

# %%
'''#INTERPOLATE AFTER
for i in range(1,18):
    data_array.append(pd.Series(data['dubai{}'.format(i)]).groupby(pd.cut(pd.Series(data['dubai{}'.format(i)]).index, bins)).sum().interpolate().values)
for i in range(1,18):
    data_array.append(pd.Series(data['sydney{}'.format(i)]).groupby(pd.cut(pd.Series(data['sydney{}'.format(i)]).index, bins)).sum().interpolate().values)
for i in range(1,18):
    data_array.append(pd.Series(data['commonwealth{}'.format(i)]).groupby(pd.cut(pd.Series(data['commonwealth{}'.format(i)]).index, bins)).sum().interpolate().values)
for i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):
    data_array.append(pd.Series(data['langford{}'.format(i)]).groupby(pd.cut(pd.Series(data['langford{}'.format(i)]).index, bins)).sum().interpolate().values)
for i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):
    data_array.append(pd.Series(data['paris{}'.format(i)]).groupby(pd.cut(pd.Series(data['paris{}'.format(i)]).index, bins)).sum().interpolate().values)
for i in (1,2,3,4,5,6,7,8,10,11,13,14,15,16,17):
    data_array.append(pd.Series(data['world{}'.format(i)]).groupby(pd.cut(pd.Series(data['world{}'.format(i)]).index, bins)).sum().interpolate().values)'''
# Out:
# "#INTERPOLATE AFTER\nfor i in range(1,18):\n    data_array.append(pd.Series(data['dubai{}'.format(i)]).groupby(pd.cut(pd.Series(data['dubai{}'.format(i)]).index, bins)).sum().interpolate().values)\nfor i in range(1,18):\n    data_array.append(pd.Series(data['sydney{}'.format(i)]).groupby(pd.cut(pd.Series(data['sydney{}'.format(i)]).index, bins)).sum().interpolate().values)\nfor i in range(1,18):\n    data_array.append(pd.Series(data['commonwealth{}'.format(i)]).groupby(pd.cut(pd.Series(data['commonwealth{}'.format(i)]).index, bins)).sum().interpolate().values)\nfor i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):\n    data_array.append(pd.Series(data['langford{}'.format(i)]).groupby(pd.cut(pd.Series(data['langford{}'.format(i)]).index, bins)).sum().interpolate().values)\nfor i in (1,2,3,4,5,6,7,8,10,11,12,13,14,15,16,17):\n    data_array.append(pd.Series(data['paris{}'.format(i)]).groupby(pd.cut(pd.Series(data['paris{}'.format(i)]).index, bins)).sum().interpolate().values)\nfor i in (
# ...

# %%
ml2 = pd.DataFrame(data_array)
ml2.to_csv('train2.csv')

# %%
for i in range(len(data_array)):
    plt.plot(data_array[i])

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
for i in range(2,7):
    kmeans = KMeans(n_clusters=i, random_state=10)
    cluster_labels = kmeans.fit_predict(ml2.dropna().values)

    silhouette_avg = silhouette_score(ml2.dropna().values,cluster_labels)
    print("For n_clusters =", i, "The average silhouette_score is :", silhouette_avg)

centers = kmeans.cluster_centers_
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.19212891831578705
# For n_clusters = 3 The average silhouette_score is : 0.17801560953684278
# For n_clusters = 4 The average silhouette_score is : 0.21819249732926904
# For n_clusters = 5 The average silhouette_score is : 0.17349583105806293
# For n_clusters = 6 The average silhouette_score is : 0.1935876281779573

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit_predict(ml2.dropna().values)
centers = kmeans.cluster_centers_
# Out:
# 'kmeans = KMeans(n_clusters=4)\nkmeans.fit_predict(ml2.dropna().values)\ncenters = kmeans.cluster_centers_'

# %%
centers
# Out:
# array([[0.729     , 0.89933333, 0.743     , 0.98033333, 1.3115    ,
#         1.44433333, 1.40233333, 1.204     , 1.07966667, 0.73233333],
#        [0.984     , 1.41      , 1.512     , 1.08      , 1.394     ,
#         3.298     , 1.736     , 1.492     , 1.042     , 0.764     ],
#        [2.92      , 2.93      , 1.91      , 0.69      , 1.38      ,
#         1.27      , 1.36      , 0.585     , 1.        , 1.485     ],
#        [1.01740741, 1.49962963, 1.4737037 , 1.07185185, 0.90481481,
#         1.04296296, 1.15888889, 1.00111111, 1.13481481, 0.93074074],
#        [0.84789474, 1.50631579, 1.57842105, 1.76210526, 1.52263158,
#         1.11315789, 1.15736842, 0.97736842, 0.71736842, 0.63578947],
#        [0.64333333, 1.04      , 1.36      , 1.43666667, 1.40333333,
#         1.68333333, 1.32666667, 1.56666667, 3.79      , 1.55666667]])

# %%
for i in range(4):
    plt.plot(centers[i])

# %%
from sklearn import metrics
from scipy.spatial.distance import cdist
import numpy as np

distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(ml2.dropna().values)
    kmeanModel.fit(ml2.dropna().values)
    distortions.append(sum(np.min(cdist(ml2.dropna().values, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / ml2.dropna().values.shape[0])

# Plot the elbow
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()
