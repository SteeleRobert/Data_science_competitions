# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline, make_pipeline
import random
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
import seaborn as sns
import math
from scipy.stats import ks_2samp
from scipy.stats import ttest_ind

import warnings
warnings.filterwarnings("ignore")
matplotlib.rcParams.update({'font.size': 24})

from jupyterthemes import jtplot
jtplot.style(theme='monokai', context='notebook', ticks=True, grid = False)

random_state = 42

# %%
listings = pd.read_csv('./listings.csv')
zipcodes = pd.Series(listings['zipcode'].unique()).dropna()
demographics = pd.read_csv('./demographics.csv')

# %%
listings['overall_activity'] = np.array(listings['availability_30'])*np.array(listings['accommodates'])

# %%
listings
# Out:
#        accommodates                                          amenities  \
# 0               2.0  {"Wireless Internet","Air Conditioning",Kitche...
# 1               4.0  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 2               1.0  {TV,"Wireless Internet","Air Conditioning",Kit...
# 3               6.0  {Internet,"Wireless Internet","Air Conditionin...
# 4               6.0  {Internet,"Wireless Internet","Free Parking on...
# ...             ...                                                ...
# 50316           2.0  {TV,"Cable TV","Wireless Internet","Pets live ...
# 50317           2.0  {"Wireless Internet",Kitchen,"Free parking on ...
# 50318          10.0  {TV,"Wireless Internet","Air conditioning",Kit...
# 50319           4.0  {TV,Internet,"Wireless Internet","Air conditio...
# 50320           8.0  {TV,"Wireless Internet","Air conditioning",Kit...
#
#        availability_30  bathrooms  bed_type  bedrooms  beds  \
# 0                    0        1.0  Real Bed       1.0   1.0
# 1                   17        1.0  Real Bed       1.0   2.0
# 2                   29        1.0  Real Bed       1.0   1.0
# 3                   28        2.5  Real Bed       1.0   6.0
# 4                   25        2.5  Real Bed       1.0   6.0
# ...                ...        ...       ...       ...   ...
# 50316               29        1.0  Real Bed       1.0   1.0
# 50317               29        1.0  Real Bed       1.0   1.0
# 50318               29        5.0  Real Bed       5.0   5.0
# 50319               28        1.0  Real Bed       2.0   2.0
# 50320               24        4.0  Real Bed       3.0   6.0
#
#       cancellation_policy       city  has_availability  ...  \
# 0                moderate  Asheville               NaN  ...
# 1                  strict  Asheville               NaN  ...
# 2                flexible  Asheville               NaN  ...
# 3                moderate  Asheville               NaN  ...
# 4                moderate  Asheville               NaN  ...
# ...                   ...        ...               ...  ...
# 50316            flexible   la habra               NaN  ...
# 50317              strict     malibu               NaN  ...
# 50318            flexible     malibu               NaN  ...
# 50319            moderate   la habra               NaN  ...
# 50320            flexible     malibu               NaN  ...
#
#        review_scores_cleanliness  review_scores_communication  \
# 0                            9.0                         10.0
# 1                           10.0                         10.0
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            9.0                          9.0
# ...                          ...                          ...
# 50316                        NaN                          NaN
# 50317                        NaN                          NaN
# 50318                        NaN                          NaN
# 50319                        NaN                          NaN
# 50320                        NaN                          NaN
#
#       review_scores_location  review_scores_rating  review_scores_value  \
# 0                        9.0                  96.0                 10.0
# 1                        9.0                  96.0                  9.0
# 2                        NaN                   NaN                  NaN
# 3                        NaN                   NaN                  NaN
# 4                        9.0                  93.0                 10.0
# ...                      ...                   ...                  ...
# 50316                    NaN                   NaN                  NaN
# 50317                    NaN                   NaN                  NaN
# 50318                    NaN                   NaN                  NaN
# 50319                    NaN                   NaN                  NaN
# 50320                    NaN                   NaN                  NaN
#
#              room_type state weekly_price  zipcode  overall_activity
# 0      Entire home/apt    NC      $650.00  28806.0               0.0
# 1      Entire home/apt    NC          NaN  28806.0              68.0
# 2         Private room    NC          NaN  28806.0              29.0
# 3          Shared room    NC          NaN  28806.0             168.0
# 4          Shared room    NC          NaN  28806.0             150.0
# ...                ...   ...          ...      ...               ...
# 50316     Private room    CA          NaN    90631              58.0
# 50317     Private room    CA          NaN    90265              58.0
# 50318  Entire home/apt    CA          NaN    90265             290.0
# 50319     Private room    CA          NaN    90631             112.0
# 50320  Entire home/apt    CA          NaN    90265             192.0
#
# [50321 rows x 30 columns]

# %%
number_of_properties = []
overall_activity = []
overall_capacity = []
overall_availability = []
dzip = {}

for z in zipcodes:
    number_of_properties.append(len(listings[listings['zipcode'] == z]))
    overall_activity.append(sum(listings[listings['zipcode'] == z]['overall_activity']))
    overall_capacity.append(sum(listings[listings['zipcode'] == z]['accommodates']))
    overall_availability.append(sum(listings[listings['zipcode'] == z]['availability_30']))
    dzip[z] = listings[listings['zipcode'] == z]['state'].unique()[0]

# %%
dfzip = pd.DataFrame()
dfzip['zipcodes'] = zipcodes
dfzip['number_of_listings'] = number_of_properties
dfzip['overall_capacity'] = overall_capacity
dfzip['overall_availability'] = overall_availability
dfzip['overall_activity'] = overall_activity

# %% [markdown]
# # Part 1: Cleaning zipcodes data

# %%
def clean(zipcode):
    # str to int
    if zipcode != zipcode:
        return np.nan
    elif  len(zipcode.split('.')) > 1:
        return int(zipcode.split('.')[0])
    elif len(zipcode.split('-')) > 1:
        return int(zipcode.split('-')[0])
    elif len(zipcode.split(':')) > 1:
        return int(zipcode.split(':')[0])
    elif len(zipcode.split(' ')) > 1:
        if len(zipcode.split(' ')) == 2:
            return int(zipcode.split(' ')[1])
        else:
            return int(zipcode.split(' ')[0])
        
    elif len(zipcode.split('\n')) > 1:
        return int(zipcode.split('\n')[0])
    else:
        return int(zipcode)

# %%
clean_zipcodes = []
states_of_clean_zipcodes = []

for i in zipcodes:
    clean_zipcodes.append(clean(i))
    states_of_clean_zipcodes.append(dzip[i])

# %%
dfzip['zipcode'] = clean_zipcodes
dfzip['state'] = states_of_clean_zipcodes
dfzip
# Out:
#     zipcodes  number_of_listings  overall_capacity  overall_availability  \
# 0    28806.0                 239             821.0                  3412
# 1    28801.0                 203             660.0                  2590
# 2    28803.0                 115             446.0                  1916
# 3    28805.0                  98             358.0                  1433
# 4    28804.0                 121             449.0                  1984
# ..       ...                 ...               ...                   ...
# 425    91361                   7              15.0                   181
# 426    91306                  39             122.0                   817
# 427    90606                   3              25.0                    28
# 428    90095                   2               9.0                    32
# 429    90602                  19             102.0                   251
#
#      overall_activity  zipcode state
# 0             11103.0    28806    NC
# 1              8991.0    28801    NC
# 2              7246.0    28803    NC
# 3              5079.0    28805    NC
# 4              7181.0    28804    NC
# ..                ...      ...   ...
# 425             397.0    91361    CA
# 426            2589.0    91306    CA
# 427             305.0    90606    CA
# 428             183.0    90095    CA
# 429            1517.0    90602    CA
#
# [429 rows x 7 columns]

# %% [markdown]
# # Part 2: Combining demographic and Airbnb data for the postcodes, adding extra features

# %%
df_new = pd.merge(dfzip, demographics, on = 'zipcode')
df_new
# Out:
#     zipcodes  number_of_listings  overall_capacity  overall_availability  \
# 0    28806.0                 239             821.0                  3412
# 1    28801.0                 203             660.0                  2590
# 2    28803.0                 115             446.0                  1916
# 3    28805.0                  98             358.0                  1433
# 4    28804.0                 121             449.0                  1984
# ..       ...                 ...               ...                   ...
# 412    91361                   7              15.0                   181
# 413    91306                  39             122.0                   817
# 414    90606                   3              25.0                    28
# 415    90095                   2               9.0                    32
# 416    90602                  19             102.0                   251
#
#      overall_activity  zipcode state  population  5_years_or_less  5-9_years  \
# 0             11103.0    28806    NC       40326             2613       2687
# 1              8991.0    28801    NC       14300              689        457
# 2              7246.0    28803    NC       31478             2083       1992
# 3              5079.0    28805    NC       18010              808       1019
# 4              7181.0    28804    NC       21047              765       1095
# ..                ...      ...   ...         ...              ...        ...
# 412             397.0    91361    CA       20831              806        900
# 413            2589.0    91306    CA       49532             3024       3230
# 414             305.0    90606    CA       32697             1772       2070
# 415             183.0    90095    CA           0                0          0
# 416            1517.0    90602    CA       27421             2053       1768
#
#      ...  $9,999_or_less  $10,000-$14,999  $15,000-$24,999  $25,000-$34,999  \
# 0    ...             7.7              9.1             13.2             11.9
# 1    ...            12.2             12.9             15.1             13.9
# 2    ...             6.7              6.8              9.5             11.8
# 3    ...             4.7              8.8             14.5             11.6
# 4    ...             5.7              5.6             10.6             11.2
# ..   ...             ...              ...              ...              ...
# 412  ...             4.1                2              4.2              5.7
# 413  ...             4.4              5.1              8.2             10.9
# 414  ...             3.9              4.4                8              9.8
# 415  ...               -                -                -                -
# 416  ...               5              5.7             13.5             11.4
#
#      $35,000-$49,999  $50,000-$64,999  $65,000-$74,999  $75,000_or_more  \
# 0               20.3               18                9             10.8
# 1               12.6             13.1              5.9             14.3
# 2               16.9             18.6              9.7             20.0
# 3               14.2             15.9             12.6             17.7
# 4               16.7             16.2              9.7             24.3
# ..               ...              ...              ...              ...
# 412              7.3             10.7               13             53.0
# 413             12.4             17.6             14.9             26.5
# 414               13             20.2             15.9             24.8
# 415                -                -                -            100.0
# 416             15.8               17             11.2             20.4
#
#      median_household_income  mean_household_income
# 0                      41208                  50635
# 1                      31359                  52163
# 2                      47474                  72934
# 3                      45335                  63223
# 4                      50193                  79470
# ..                       ...                    ...
# 412                   104807                 156405
# 413                    61529                  74726
# 414                    64393                  74385
# 415                        -                      -
# 416                    48109                  66575
#
# [417 rows x 32 columns]

# %%
l1 = list(dfzip['zipcode'])
l2 = list(df_new['zipcode'])

list(set(l1) - set(l2))
# whatever
# Out:
# [90625,
#  999041,
#  91523,
#  70148,
#  9004,
#  91308,
#  90929,
#  210,
#  78774,
#  90840,
#  91802,
#  701115]

# %%
df_new['median_household_income'] = df_new['median_household_income'].apply(lambda el: np.nan if el == '-' else float(el))
df_new['mean_household_income'] = df_new['mean_household_income'].apply(lambda el: np.nan if el == '-' else float(el))

df_new['$9,999_or_less'] = df_new['$9,999_or_less'].apply(lambda el: np.nan if el == '-' else float(el))
df_new['$10,000-$14,999'] = df_new['$10,000-$14,999'].apply(lambda el: np.nan if el == '-' else float(el))

df_new['$15,000-$24,999'] = df_new['$15,000-$24,999'].apply(lambda el: np.nan if el == '-' else float(el))
df_new['$25,000-$34,999'] = df_new['$25,000-$34,999'].apply(lambda el: np.nan if el == '-' else float(el))
df_new['$35,000-$49,999'] = df_new['$35,000-$49,999'].apply(lambda el: np.nan if el == '-' else float(el))
df_new['$50,000-$64,999'] = df_new['$50,000-$64,999'].apply(lambda el: np.nan if el == '-' else float(el))
df_new['$65,000-$74,999'] = df_new['$65,000-$74,999'].apply(lambda el: np.nan if el == '-' else float(el))

df_new['5_years_or_less_fr'] = df_new['5_years_or_less']/df_new['population']
df_new['5-9_years_fr'] = df_new['5-9_years']/df_new['population']
df_new['10-14_years_fr'] = df_new['10-14_years']/df_new['population']
df_new['15-19_years_fr'] = df_new['15-19_years']/df_new['population']
df_new['20-24_years_fr'] = df_new['20-24_years']/df_new['population']
df_new['25-34_years_fr'] = df_new['25-34_years']/df_new['population']
df_new['35-44_years_fr'] = df_new['35-44_years']/df_new['population']
df_new['45-54_years_fr'] = df_new['45-54_years']/df_new['population']

df_new['55-59_years_fr'] = df_new['55-59_years']/df_new['population']
df_new['60-64_years_fr'] = df_new['60-64_years']/df_new['population']
df_new['65-74_years_fr'] = df_new['65-74_years']/df_new['population']
df_new['75-84_years_fr'] = df_new['75-84_years']/df_new['population']
df_new['85_years_or_more_fr'] = df_new['85_years_or_more']/df_new['population']

# %%
corr = df_new.corr()
corr
# Out:
#                          number_of_listings  overall_capacity  \
# number_of_listings                 1.000000          0.982450
# overall_capacity                   0.982450          1.000000
# overall_availability               0.985631          0.971315
# overall_activity                   0.961373          0.983913
# zipcode                           -0.033753         -0.085906
# population                         0.026056         -0.012881
# 5_years_or_less                   -0.080049         -0.101110
# 5-9_years                         -0.128588         -0.142824
# 10-14_years                       -0.171456         -0.185496
# 15-19_years                       -0.105522         -0.126280
# 20-24_years                        0.087925          0.047555
# 25-34_years                        0.255883          0.203044
# 35-44_years                        0.091616          0.043048
# 45-54_years                       -0.014588         -0.052875
# 55-59_years                       -0.012664         -0.043162
# 60-64_years                        0.014701         -0.016502
# 65-74_years                       -0.001873         -0.037792
# 75-84_years                       -0.036174         -0.070757
# 85_years_or_more                   0.042838         -0.000125
# households                         0.241940          0.188353
# $9,999_or_less                     0.212583          0.224615
# $10,000-$14,999                    0.110178          0.090842
# $15,000-$24,999                    0.050422          0.036230
# $25,000-$34,999                   -0.017028         -0.034756
# $35,000-$49,999                   -0.064975         -0.076150
# $50,000-$64,999                   -0.129035         -0.138373
# $65,000-$74,999                   -0.188322         -0.193983
# $75,000_or_more                   -0.037350         -0.023367
# median_household_income           -0.082237         -0.062510
# mean_household_income              0.025010          0.049624
# 5_years_or_less_fr                -0.217310         -0.206070
# 5-9_years_fr                      -0.326329         -0.299517
# 10-14_years_fr                    -0.381738         -0.359681
# 15-19_years_fr                    -0.178429         -0.171097
# 20-24_years_fr                     0.130111          0.112096
# 25-34_years_fr                     0.468113          0.445445
# 35-44_years_fr                     0.204793          0.169193
# 45-54_years_fr                    -0.157687         -0.150035
# 55-59_years_fr                    -0.114754         -0.086705
# 60-64_years_fr                    -0.061947         -0.032754
# 65-74_years_fr                    -0.088995         -0.075226
# 75-84_years_fr                    -0.108227         -0.104509
# 85_years_or_more_fr               -0.035872         -0.040323
#
#                          overall_availability  overall_activity   zipcode  \
# number_of_listings                   0.985631          0.961373 -0.033753
# overall_capacity                     0.971315          0.983913 -0.085906
# overall_availability                 1.000000          0.978987 -0.029607
# overall_activity                     0.978987          1.000000 -0.081771
# zipcode                             -0.029607         -0.081771  1.000000
# population                           0.026292         -0.023301  0.222710
# 5_years_or_less                     -0.082231         -0.112979  0.168821
# 5-9_years                           -0.127211         -0.149863  0.172502
# 10-14_years                         -0.167082         -0.189194  0.219016
# 15-19_years                         -0.114878         -0.140915  0.215199
# 20-24_years                          0.067236          0.021196  0.182684
# 25-34_years                          0.245915          0.180917  0.157430
# 35-44_years                          0.090354          0.029887  0.224736
# 45-54_years                         -0.004561         -0.054327  0.250469
# 55-59_years                          0.002102         -0.040023  0.214752
# 60-64_years                          0.031759         -0.011765  0.187182
# 65-74_years                          0.015148         -0.029968  0.204074
# 75-84_years                         -0.020116         -0.060252  0.229533
# 85_years_or_more                     0.063511          0.015238  0.249779
# households                           0.242696          0.176768  0.145927
# $9,999_or_less                       0.206680          0.229279 -0.154340
# $10,000-$14,999                      0.111885          0.099217 -0.011473
# $15,000-$24,999                      0.050769          0.034496 -0.103211
# $25,000-$34,999                     -0.017923         -0.043918 -0.182272
# $35,000-$49,999                     -0.072391         -0.095259 -0.211678
# $50,000-$64,999                     -0.141718         -0.163775 -0.099848
# $65,000-$74,999                     -0.200054         -0.211769  0.026301
# $75,000_or_more                     -0.029941         -0.011238  0.189939
# median_household_income             -0.071554         -0.047313  0.170686
# mean_household_income                0.042623          0.076571  0.146426
# 5_years_or_less_fr                  -0.224876         -0.220570  0.014845
# 5-9_years_fr                        -0.323403         -0.299545  0.042817
# 10-14_years_fr                      -0.373916         -0.353839  0.135869
# 15-19_years_fr                      -0.195502         -0.185913  0.051256
# 20-24_years_fr                       0.091278          0.074613 -0.019880
# 25-34_years_fr                       0.447769          0.419330 -0.100466
# 35-44_years_fr                       0.199427          0.157797  0.091933
# 45-54_years_fr                      -0.125415         -0.115573  0.054914
# 55-59_years_fr                      -0.081173         -0.048657 -0.035436
# 60-64_years_fr                      -0.026155          0.008285 -0.158794
# 65-74_years_fr                      -0.058644         -0.038145 -0.092425
# 75-84_years_fr                      -0.084695         -0.072787  0.049445
# 85_years_or_more_fr                 -0.018159         -0.018083  0.059951
#
#                          population  5_years_or_less  5-9_years  10-14_years  \
# number_of_listings         0.026056        -0.080049  -0.128588    -0.171456
# overall_capacity          -0.012881        -0.101110  -0.142824    -0.185496
# overall_availability       0.026292        -0.082231  -0.127211    -0.167082
# overall_activity          -0.023301        -0.112979  -0.149863    -0.189194
# zipcode                    0.222710         0.168821   0.172502     0.219016
# population                 1.000000         0.931885   0.926850     0.926512
# 5_years_or_less            0.931885         1.000000   0.971923     0.944021
# 5-9_years                  0.926850         0.971923   1.000000     0.971849
# 10-14_years                0.926512         0.944021   0.971849     1.000000
# 15-19_years                0.881703         0.848300   0.870481     0.888428
# 20-24_years                0.834518         0.762453   0.746210     0.733538
# 25-34_years                0.899591         0.836963   0.783483     0.741091
# 35-44_years                0.971828         0.913154   0.896429     0.883288
# 45-54_years                0.965077         0.867592   0.876648     0.899692
# 55-59_years                0.932187         0.806642   0.820332     0.849169
# 60-64_years                0.894005         0.743670   0.752993     0.782726
# 65-74_years                0.829793         0.647342   0.668873     0.712836
# 75-84_years                0.753058         0.567229   0.588089     0.633098
# 85_years_or_more           0.603721         0.394053   0.399574     0.446977
# households                 0.904542         0.775891   0.740662     0.722142
# $9,999_or_less            -0.072754        -0.033846  -0.073375    -0.108144
# $10,000-$14,999            0.096483         0.155761   0.103474     0.073671
# $15,000-$24,999            0.274131         0.361637   0.309810     0.262156
# $25,000-$34,999            0.301334         0.399498   0.357853     0.310158
# $35,000-$49,999            0.321497         0.412482   0.369757     0.335629
# $50,000-$64,999            0.211861         0.241886   0.210396     0.211690
# $65,000-$74,999            0.036336        -0.013918   0.004272     0.041437
# $75,000_or_more           -0.307237        -0.383610  -0.324863    -0.285176
# median_household_income   -0.240706        -0.304111  -0.234587    -0.193111
# mean_household_income     -0.276548        -0.347556  -0.289675    -0.256047
# 5_years_or_less_fr         0.327133         0.563324   0.499030     0.444319
# 5-9_years_fr               0.297546         0.455256   0.544958     0.494021
# 10-14_years_fr             0.216627         0.312555   0.387361     0.450856
# 15-19_years_fr             0.133714         0.140355   0.176200     0.202498
# 20-24_years_fr             0.145798         0.101915   0.074871     0.062399
# 25-34_years_fr             0.016201         0.013498  -0.083238    -0.153413
# 35-44_years_fr             0.013426         0.037306   0.002349    -0.034740
# 45-54_years_fr            -0.201373        -0.242982  -0.192725    -0.138379
# 55-59_years_fr            -0.257528        -0.315798  -0.279668    -0.231953
# 60-64_years_fr            -0.300994        -0.384710  -0.358299    -0.317574
# 65-74_years_fr            -0.315404        -0.416054  -0.374994    -0.330155
# 75-84_years_fr            -0.225442        -0.323632  -0.296164    -0.257476
# 85_years_or_more_fr       -0.199610        -0.273898  -0.269636    -0.240977
#
#                          15-19_years  ...  15-19_years_fr  20-24_years_fr  \
# number_of_listings         -0.105522  ...       -0.178429        0.130111
# overall_capacity           -0.126280  ...       -0.171097        0.112096
# overall_availability       -0.114878  ...       -0.195502        0.091278
# overall_activity           -0.140915  ...       -0.185913        0.074613
# zipcode                     0.215199  ...        0.051256       -0.019880
# population                  0.881703  ...        0.133714        0.145798
# 5_years_or_less             0.848300  ...        0.140355        0.101915
# 5-9_years                   0.870481  ...        0.176200        0.074871
# 10-14_years                 0.888428  ...        0.202498        0.062399
# 15-19_years                 1.000000  ...        0.408978        0.368444
# 20-24_years                 0.901736  ...        0.334808        0.570440
# 25-34_years                 0.691353  ...       -0.009052        0.185056
# 35-44_years                 0.790328  ...        0.041308        0.059429
# 45-54_years                 0.808256  ...        0.077222        0.008688
# 55-59_years                 0.768403  ...        0.063135       -0.010713
# 60-64_years                 0.708569  ...        0.024202       -0.038445
# 65-74_years                 0.652542  ...        0.019718       -0.065376
# 75-84_years                 0.586741  ...        0.009346       -0.057355
# 85_years_or_more            0.451310  ...       -0.012595       -0.040949
# households                  0.667597  ...       -0.037972        0.076656
# $9,999_or_less              0.050994  ...        0.201934        0.489991
# $10,000-$14,999             0.124759  ...        0.049429        0.303492
# $15,000-$24,999             0.285562  ...        0.148095        0.350415
# $25,000-$34,999             0.289382  ...        0.163720        0.252518
# $35,000-$49,999             0.286284  ...        0.141974        0.155849
# $50,000-$64,999             0.153548  ...        0.015449        0.007785
# $65,000-$74,999            -0.021655  ...       -0.076647       -0.213631
# $75,000_or_more            -0.307139  ...        0.031510       -0.252053
# median_household_income    -0.251978  ...       -0.150149       -0.421440
# mean_household_income      -0.285325  ...       -0.190848       -0.379150
# 5_years_or_less_fr          0.309014  ...        0.004885       -0.111436
# 5-9_years_fr                0.342425  ...        0.121141       -0.220051
# 10-14_years_fr              0.299014  ...        0.154454       -0.224453
# 15-19_years_fr              0.408978  ...        1.000000        0.675220
# 20-24_years_fr              0.368444  ...        0.675220        1.000000
# 25-34_years_fr             -0.156272  ...       -0.394378        0.132509
# 35-44_years_fr             -0.186982  ...       -0.493256       -0.379828
# 45-54_years_fr             -0.275730  ...       -0.365522       -0.589933
# 55-59_years_fr             -0.302041  ...       -0.293025       -0.458206
# 60-64_years_fr             -0.379688  ...       -0.356978       -0.498797
# 65-74_years_fr             -0.362132  ...       -0.285023       -0.439663
# 75-84_years_fr             -0.270828  ...       -0.246662       -0.340939
# 85_years_or_more_fr        -0.221801  ...       -0.178277       -0.180624
#
#                          25-34_years_fr  35-44_years_fr  45-54_years_fr  \
# number_of_listings             0.468113        0.204793       -0.157687
# overall_capacity               0.445445        0.169193       -0.150035
# overall_availability           0.447769        0.199427       -0.125415
# overall_activity               0.419330        0.157797       -0.115573
# zipcode                       -0.100466        0.091933        0.054914
# population                     0.016201        0.013426       -0.201373
# 5_years_or_less                0.013498        0.037306       -0.242982
# 5-9_years                     -0.083238        0.002349       -0.192725
# 10-14_years                   -0.153413       -0.034740       -0.138379
# 15-19_years                   -0.156272       -0.186982       -0.275730
# 20-24_years                    0.076547       -0.157194       -0.413177
# 25-34_years                    0.362717        0.161872       -0.327287
# 35-44_years                    0.104415        0.191530       -0.185877
# 45-54_years                   -0.076838        0.025481       -0.003477
# 55-59_years                   -0.111577       -0.031720       -0.019756
# 60-64_years                   -0.099534       -0.032168       -0.034173
# 65-74_years                   -0.167423       -0.077216        0.012953
# 75-84_years                   -0.185689       -0.114558        0.019455
# 85_years_or_more              -0.143635       -0.113109        0.001891
# households                     0.193175        0.126221       -0.166044
# $9,999_or_less                 0.282232       -0.247478       -0.275090
# $10,000-$14,999                0.258090       -0.067495       -0.315144
# $15,000-$24,999                0.277458       -0.121492       -0.384312
# $25,000-$34,999                0.187438       -0.141503       -0.302863
# $35,000-$49,999                0.183266        0.019872       -0.404820
# $50,000-$64,999                0.210265        0.036236       -0.089090
# $65,000-$74,999               -0.095497        0.044146        0.204266
# $75,000_or_more               -0.368352        0.078549        0.338515
# median_household_income       -0.405807        0.149849        0.409510
# mean_household_income         -0.334910        0.088490        0.341445
# 5_years_or_less_fr            -0.061169        0.186212       -0.240754
# 5-9_years_fr                  -0.371912        0.037894       -0.014029
# 10-14_years_fr                -0.529464        0.105048        0.062277
# 15-19_years_fr                -0.394378       -0.493256       -0.365522
# 20-24_years_fr                 0.132509       -0.379828       -0.589933
# 25-34_years_fr                 1.000000        0.324710       -0.262303
# 35-44_years_fr                 0.324710        1.000000        0.008302
# 45-54_years_fr                -0.262303        0.008302        1.000000
# 55-59_years_fr                -0.326202       -0.178603        0.502643
# 60-64_years_fr                -0.286941       -0.165260        0.409944
# 65-74_years_fr                -0.391309       -0.248163        0.343771
# 75-84_years_fr                -0.339724       -0.252745        0.217561
# 85_years_or_more_fr           -0.248463       -0.228574        0.078528
#
#                          55-59_years_fr  60-64_years_fr  65-74_years_fr  \
# number_of_listings            -0.114754       -0.061947       -0.088995
# overall_capacity              -0.086705       -0.032754       -0.075226
# overall_availability          -0.081173       -0.026155       -0.058644
# overall_activity              -0.048657        0.008285       -0.038145
# zipcode                       -0.035436       -0.158794       -0.092425
# population                    -0.257528       -0.300994       -0.315404
# 5_years_or_less               -0.315798       -0.384710       -0.416054
# 5-9_years                     -0.279668       -0.358299       -0.374994
# 10-14_years                   -0.231953       -0.317574       -0.330155
# 15-19_years                   -0.302041       -0.379688       -0.362132
# 20-24_years                   -0.397375       -0.449405       -0.438245
# 25-34_years                   -0.366386       -0.383526       -0.427908
# 35-44_years                   -0.280054       -0.320712       -0.350442
# 45-54_years                   -0.135469       -0.196314       -0.212130
# 55-59_years                    0.001716       -0.088212       -0.118887
# 60-64_years                   -0.028764        0.060275       -0.030461
# 65-74_years                    0.016857        0.066957        0.138131
# 75-84_years                    0.030259        0.071471        0.139765
# 85_years_or_more               0.046460        0.105965        0.179008
# households                    -0.209318       -0.202988       -0.232701
# $9,999_or_less                -0.197280       -0.182365       -0.279419
# $10,000-$14,999               -0.134280       -0.185314       -0.275605
# $15,000-$24,999               -0.304514       -0.329352       -0.389195
# $25,000-$34,999               -0.329551       -0.273685       -0.348536
# $35,000-$49,999               -0.362924       -0.308442       -0.374409
# $50,000-$64,999               -0.081926       -0.176632       -0.171825
# $65,000-$74,999                0.189194        0.143096        0.166554
# $75,000_or_more                0.274580        0.294676        0.397910
# median_household_income        0.286612        0.306148        0.424761
# mean_household_income          0.285460        0.332487        0.483025
# 5_years_or_less_fr            -0.355690       -0.358970       -0.453439
# 5-9_years_fr                  -0.202699       -0.235048       -0.282738
# 10-14_years_fr                -0.102524       -0.130158       -0.214452
# 15-19_years_fr                -0.293025       -0.356978       -0.285023
# 20-24_years_fr                -0.458206       -0.498797       -0.439663
# 25-34_years_fr                -0.326202       -0.286941       -0.391309
# 35-44_years_fr                -0.178603       -0.165260       -0.248163
# 45-54_years_fr                 0.502643        0.409944        0.343771
# 55-59_years_fr                 1.000000        0.645529        0.586432
# 60-64_years_fr                 0.645529        1.000000        0.689139
# 65-74_years_fr                 0.586432        0.689139        1.000000
# 75-84_years_fr                 0.402457        0.520915        0.757234
# 85_years_or_more_fr            0.253003        0.347971        0.608572
#
#                          75-84_years_fr  85_years_or_more_fr
# number_of_listings            -0.108227            -0.035872
# overall_capacity              -0.104509            -0.040323
# overall_availability          -0.084695            -0.018159
# overall_activity              -0.072787            -0.018083
# zipcode                        0.049445             0.059951
# population                    -0.225442            -0.199610
# 5_years_or_less               -0.323632            -0.273898
# 5-9_years                     -0.296164            -0.269636
# 10-14_years                   -0.257476            -0.240977
# 15-19_years                   -0.270828            -0.221801
# 20-24_years                   -0.318793            -0.232182
# 25-34_years                   -0.331699            -0.245303
# 35-44_years                   -0.268626            -0.225891
# 45-54_years                   -0.144326            -0.157774
# 55-59_years                   -0.067919            -0.102685
# 60-64_years                   -0.003571            -0.055973
# 65-74_years                    0.126763             0.033252
# 75-84_years                    0.304392             0.137717
# 85_years_or_more               0.309272             0.363700
# households                    -0.165517            -0.130549
# $9,999_or_less                -0.208635            -0.107690
# $10,000-$14,999               -0.120599            -0.106743
# $15,000-$24,999               -0.253580            -0.201192
# $25,000-$34,999               -0.272036            -0.221411
# $35,000-$49,999               -0.318676            -0.312274
# $50,000-$64,999               -0.204130            -0.194906
# $65,000-$74,999                0.080849            -0.015077
# $75,000_or_more                0.308384             0.271639
# median_household_income        0.309079             0.244315
# mean_household_income          0.391152             0.348154
# 5_years_or_less_fr            -0.383803            -0.319016
# 5-9_years_fr                  -0.275672            -0.331899
# 10-14_years_fr                -0.218676            -0.265347
# 15-19_years_fr                -0.246662            -0.178277
# 20-24_years_fr                -0.340939            -0.180624
# 25-34_years_fr                -0.339724            -0.248463
# 35-44_years_fr                -0.252745            -0.228574
# 45-54_years_fr                 0.217561             0.078528
# 55-59_years_fr                 0.402457             0.253003
# 60-64_years_fr                 0.520915             0.347971
# 65-74_years_fr                 0.757234             0.608572
# 75-84_years_fr                 1.000000             0.703141
# 85_years_or_more_fr            0.703141             1.000000
#
# [43 rows x 43 columns]

# %% [markdown]
# # Part 2.1: Grouping the data by states

# %%
states = df_new['state'].unique()

statedfs = {}

for s in states:
    statedfs[s] = df_new[df_new['state'] == s]
    
for s in statedfs.keys():
    print(len(statedfs[s]))
    corr = statedfs[s].corr()
    print(corr)
# Out:
# 10
#                          number_of_listings  overall_capacity  \
# number_of_listings                 1.000000          0.996442
# overall_capacity                   0.996442          1.000000
# overall_availability               0.990867          0.997191
# overall_activity                   0.981912          0.993196
# zipcode                            0.660516          0.683550
# population                         0.540037          0.570155
# 5_years_or_less                    0.517065          0.543077
# 5-9_years                          0.430716          0.463881
# 10-14_years                        0.404545          0.422923
# 15-19_years                        0.284427          0.318988
# 20-24_years                        0.707936          0.722147
# 25-34_years                        0.726404          0.741976
# 35-44_years                        0.543686          0.569491
# 45-54_years                        0.372245          0.388860
# 55-59_years                        0.481353          0.519941
# 60-64_years                        0.386360          0.417892
# 65-74_years                        0.190916          0.246760
# 75-84_years                        0.394551          0.446557
# 85_years_or_more                   0.472068          0.527019
# households                         0.589640          0.622049
# $9,999_or_less                     0.767811          0.730888
# $10,000-$14,999                    0.747256          0.725363
# $15,000-$24,999                    0.632062          0.611551
# $25,000-$34,999                    0.230585          0.222538
# $35,000-$49,999                   -0.038241         -0.008115
# $50,000-$64,999                   -0.664434         -0.644546
# $65,000-$74,999                   -0.733177         -0.727730
# $75,000_or_more                   -0.491213         -0.472775
# median_household_income           -0.717130         -0.703619
# mean_household_income             -0.515174         -0.476640
# 5_years_or_less_fr                 0.200521          0.209335
# 5-9_years_fr                      -0.158956         -0.113367
# 10-14_years_fr                    -0.373090         -0.390819
# 15-19_years_fr                    -0.384975         -0.377551
# 20-24_years_fr                     0.357736          0.331799
# 25-34_years_fr                     0.875861          0.860034
# 35-44_years_fr                     0.159566          0.163971
# 45-54_years_fr                    -0.301690         -0.342210
# 55-59_years_fr                    -0.333803         -0.345778
# 60-64_years_fr                    -0.350287         -0.353168
# 65-74_years_fr                    -0.621285         -0.598499
# 75-84_years_fr                    -0.167020         -0.110876
# 85_years_or_more_fr                0.211860          0.262730
#
#                          overall_availability  overall_activity   zipcode  \
# number_of_listings                   0.990867          0.981912  0.660516
# overall_capacity                     0.997191          0.993196  0.683550
# overall_availability                 1.000000          0.995676  0.659281
# overall_activity                     0.995676          1.000000  0.680390
# zipcode                              0.659281          0.680390  1.000000
# population                           0.609681          0.593973  0.242668
# 5_years_or_less                      0.574274          0.556135  0.221136
# 5-9_years                            0.503378          0.484289  0.190515
# 10-14_years                          0.461233          0.435848 -0.040481
# 15-19_years                          0.382139          0.372545  0.103531
# 20-24_years                          0.763071          0.736552  0.361108
# 25-34_years                          0.761281          0.736472  0.372143
# 35-44_years                          0.605290          0.587659  0.169177
# 45-54_years                          0.439070          0.418153 -0.092215
# 55-59_years                          0.552807          0.554759  0.415996
# 60-64_years                          0.448911          0.436737  0.280509
# 65-74_years                          0.286720          0.300839  0.322621
# 75-84_years                          0.488426          0.493711  0.333616
# 85_years_or_more                     0.565306          0.592568  0.361517
# households                           0.656163          0.646290  0.311978
# $9,999_or_less                       0.708645          0.706696  0.358082
# $10,000-$14,999                      0.694788          0.697058  0.584796
# $15,000-$24,999                      0.603287          0.592091  0.309881
# $25,000-$34,999                      0.198465          0.221876  0.312825
# $35,000-$49,999                     -0.000837         -0.001658 -0.058564
# $50,000-$64,999                     -0.614304         -0.631298 -0.533238
# $65,000-$74,999                     -0.733731         -0.745748 -0.437896
# $75,000_or_more                     -0.438658         -0.424104 -0.281882
# median_household_income             -0.675742         -0.692232 -0.498378
# mean_household_income               -0.433764         -0.406188 -0.255311
# 5_years_or_less_fr                   0.217250          0.198723 -0.014600
# 5-9_years_fr                        -0.070768         -0.083322 -0.114441
# 10-14_years_fr                      -0.387240         -0.405314 -0.784031
# 15-19_years_fr                      -0.339987         -0.344703 -0.197501
# 20-24_years_fr                       0.335410          0.321133  0.255586
# 25-34_years_fr                       0.839993          0.825917  0.479007
# 35-44_years_fr                       0.171718          0.179525 -0.266100
# 45-54_years_fr                      -0.316810         -0.337677 -0.805008
# 55-59_years_fr                      -0.396602         -0.371205  0.309074
# 60-64_years_fr                      -0.384816         -0.380857  0.138236
# 65-74_years_fr                      -0.616787         -0.594442  0.081289
# 75-84_years_fr                      -0.093215         -0.060280  0.259491
# 85_years_or_more_fr                  0.274859          0.333647  0.360953
#
#                          population  5_years_or_less  5-9_years  10-14_years  \
# number_of_listings         0.540037         0.517065   0.430716     0.404545
# overall_capacity           0.570155         0.543077   0.463881     0.422923
# overall_availability       0.609681         0.574274   0.503378     0.461233
# overall_activity           0.593973         0.556135   0.484289     0.435848
# zipcode                    0.242668         0.221136   0.190515    -0.040481
# population                 1.000000         0.968283   0.986120     0.934839
# 5_years_or_less            0.968283         1.000000   0.970381     0.914797
# 5-9_years                  0.986120         0.970381   1.000000     0.938019
# 10-14_years                0.934839         0.914797   0.938019     1.000000
# 15-19_years                0.804701         0.702595   0.782619     0.690172
# 20-24_years                0.841433         0.758637   0.782321     0.728361
# 25-34_years                0.932851         0.952784   0.909488     0.870342
# 35-44_years                0.975204         0.953563   0.964877     0.962822
# 45-54_years                0.922402         0.893818   0.900174     0.929684
# 55-59_years                0.933709         0.871602   0.914502     0.796553
# 60-64_years                0.905755         0.839412   0.907534     0.831640
# 65-74_years                0.796344         0.705058   0.812148     0.662329
# 75-84_years                0.914301         0.838281   0.913010     0.791395
# 85_years_or_more           0.806535         0.805287   0.774726     0.629156
# households                 0.989507         0.968129   0.969576     0.904626
# $9,999_or_less             0.131768         0.169255  -0.003727     0.073937
# $10,000-$14,999            0.277280         0.252031   0.167725     0.196946
# $15,000-$24,999            0.360892         0.252522   0.254327     0.340212
# $25,000-$34,999            0.218004         0.160061   0.165205     0.216417
# $35,000-$49,999            0.226632         0.287656   0.310912     0.314988
# $50,000-$64,999            0.171298         0.226814   0.305213     0.274531
# $65,000-$74,999           -0.512414        -0.415644  -0.377056    -0.384855
# $75,000_or_more           -0.387101        -0.435257  -0.373457    -0.492215
# median_household_income   -0.323043        -0.282791  -0.213340    -0.293409
# mean_household_income     -0.252344        -0.304235  -0.222944    -0.357914
# 5_years_or_less_fr         0.616643         0.789490   0.664426     0.629482
# 5-9_years_fr               0.700039         0.672947   0.792560     0.711594
# 10-14_years_fr            -0.051700         0.001910   0.008457     0.296809
# 15-19_years_fr            -0.244756        -0.309294  -0.227687    -0.316581
# 20-24_years_fr            -0.220722        -0.277373  -0.308720    -0.331962
# 25-34_years_fr             0.531698         0.586653   0.448699     0.473740
# 35-44_years_fr             0.316947         0.306027   0.305729     0.496485
# 45-54_years_fr            -0.132064        -0.109695  -0.162651     0.046363
# 55-59_years_fr            -0.765080        -0.747253  -0.746850    -0.859187
# 60-64_years_fr            -0.363183        -0.415589  -0.318964    -0.386415
# 65-74_years_fr            -0.586291        -0.595028  -0.495128    -0.638539
# 75-84_years_fr             0.134241        -0.005557   0.165980     0.007642
# 85_years_or_more_fr        0.053662         0.083973   0.008702    -0.166572
#
#                          15-19_years  ...  15-19_years_fr  20-24_years_fr  \
# number_of_listings          0.284427  ...       -0.384975        0.357736
# overall_capacity            0.318988  ...       -0.377551        0.331799
# overall_availability        0.382139  ...       -0.339987        0.335410
# overall_activity            0.372545  ...       -0.344703        0.321133
# zipcode                     0.103531  ...       -0.197501        0.255586
# population                  0.804701  ...       -0.244756       -0.220722
# 5_years_or_less             0.702595  ...       -0.309294       -0.277373
# 5-9_years                   0.782619  ...       -0.227687       -0.308720
# 10-14_years                 0.690172  ...       -0.316581       -0.331962
# 15-19_years                 1.000000  ...        0.345473        0.126383
# 20-24_years                 0.846888  ...        0.082680        0.324574
# 25-34_years                 0.599981  ...       -0.419949       -0.140330
# 35-44_years                 0.740255  ...       -0.298287       -0.227772
# 45-54_years                 0.816719  ...       -0.139010       -0.215110
# 55-59_years                 0.775356  ...       -0.248989       -0.276528
# 60-64_years                 0.680386  ...       -0.356400       -0.433742
# 65-74_years                 0.742347  ...       -0.097563       -0.395719
# 75-84_years                 0.775987  ...       -0.210575       -0.349293
# 85_years_or_more            0.690357  ...       -0.167831       -0.206229
# households                  0.742113  ...       -0.340342       -0.263441
# $9,999_or_less             -0.045898  ...       -0.316903        0.466819
# $10,000-$14,999            -0.047220  ...       -0.601326        0.097937
# $15,000-$24,999             0.088762  ...       -0.598813       -0.053417
# $25,000-$34,999             0.016293  ...       -0.470568       -0.235069
# $35,000-$49,999             0.120938  ...        0.009954       -0.149675
# $50,000-$64,999             0.270054  ...        0.264015       -0.502531
# $65,000-$74,999            -0.400817  ...        0.346619       -0.167228
# $75,000_or_more             0.114056  ...        0.749244        0.281782
# median_household_income     0.023269  ...        0.673179        0.003731
# mean_household_income       0.242233  ...        0.762762        0.179114
# 5_years_or_less_fr          0.289777  ...       -0.338759       -0.406772
# 5-9_years_fr                0.614555  ...       -0.061338       -0.615711
# 10-14_years_fr             -0.218179  ...       -0.227060       -0.417780
# 15-19_years_fr              0.345473  ...        1.000000        0.593965
# 20-24_years_fr              0.126383  ...        0.593965        1.000000
# 25-34_years_fr              0.074063  ...       -0.713760       -0.012832
# 35-44_years_fr              0.113385  ...       -0.367766       -0.253484
# 45-54_years_fr              0.063900  ...        0.240593        0.091582
# 55-59_years_fr             -0.654889  ...        0.131193        0.152297
# 60-64_years_fr             -0.455427  ...       -0.260218       -0.416228
# 65-74_years_fr             -0.394262  ...        0.335796       -0.094588
# 75-84_years_fr              0.175431  ...       -0.055471       -0.416034
# 85_years_or_more_fr         0.098059  ...        0.037729        0.055038
#
#                          25-34_years_fr  35-44_years_fr  45-54_years_fr  \
# number_of_listings             0.875861        0.159566       -0.301690
# overall_capacity               0.860034        0.163971       -0.342210
# overall_availability           0.839993        0.171718       -0.316810
# overall_activity               0.825917        0.179525       -0.337677
# zipcode                        0.479007       -0.266100       -0.805008
# population                     0.531698        0.316947       -0.132064
# 5_years_or_less                0.586653        0.306027       -0.109695
# 5-9_years                      0.448699        0.305729       -0.162651
# 10-14_years                    0.473740        0.496485        0.046363
# 15-19_years                    0.074063        0.113385        0.063900
# 20-24_years                    0.483793        0.215398       -0.098732
# 25-34_years                    0.759642        0.326178       -0.216123
# 35-44_years                    0.555623        0.501640       -0.092325
# 45-54_years                    0.417223        0.364616        0.254187
# 55-59_years                    0.456580        0.166716       -0.297579
# 60-64_years                    0.427683        0.142267       -0.277195
# 65-74_years                    0.129562        0.015172       -0.378065
# 75-84_years                    0.342993        0.153526       -0.332724
# 85_years_or_more               0.440290        0.096441       -0.181276
# households                     0.605474        0.294460       -0.189242
# $9,999_or_less                 0.763098        0.062718        0.147388
# $10,000-$14,999                0.783717       -0.040201       -0.269026
# $15,000-$24,999                0.669150        0.097384       -0.090966
# $25,000-$34,999                0.336417        0.255786       -0.188547
# $35,000-$49,999               -0.057499        0.620199       -0.227429
# $50,000-$64,999               -0.510738        0.189410        0.222291
# $65,000-$74,999               -0.681710       -0.277203       -0.012012
# $75,000_or_more               -0.681301       -0.421888        0.291690
# median_household_income       -0.771492       -0.309929        0.228524
# mean_household_income         -0.728124       -0.364036        0.190806
# 5_years_or_less_fr             0.467269        0.189228        0.078578
# 5-9_years_fr                  -0.084964        0.223247       -0.161706
# 10-14_years_fr                -0.134409        0.623112        0.475269
# 15-19_years_fr                -0.713760       -0.367766        0.240593
# 20-24_years_fr                -0.012832       -0.253484        0.091582
# 25-34_years_fr                 1.000000        0.267091       -0.166900
# 35-44_years_fr                 0.267091        1.000000        0.205859
# 45-54_years_fr                -0.166900        0.205859        1.000000
# 55-59_years_fr                -0.370280       -0.568389       -0.387732
# 60-64_years_fr                -0.239597       -0.461560       -0.410550
# 65-74_years_fr                -0.709397       -0.582744       -0.455076
# 75-84_years_fr                -0.267631       -0.218319       -0.542748
# 85_years_or_more_fr            0.114661       -0.309668       -0.200463
#
#                          55-59_years_fr  60-64_years_fr  65-74_years_fr  \
# number_of_listings            -0.333803       -0.350287       -0.621285
# overall_capacity              -0.345778       -0.353168       -0.598499
# overall_availability          -0.396602       -0.384816       -0.616787
# overall_activity              -0.371205       -0.380857       -0.594442
# zipcode                        0.309074        0.138236        0.081289
# population                    -0.765080       -0.363183       -0.586291
# 5_years_or_less               -0.747253       -0.415589       -0.595028
# 5-9_years                     -0.746850       -0.318964       -0.495128
# 10-14_years                   -0.859187       -0.386415       -0.638539
# 15-19_years                   -0.654889       -0.455427       -0.394262
# 20-24_years                   -0.664219       -0.536596       -0.609343
# 25-34_years                   -0.698911       -0.396987       -0.659396
# 35-44_years                   -0.819775       -0.451895       -0.657482
# 45-54_years                   -0.887485       -0.474485       -0.711268
# 55-59_years                   -0.527975       -0.118986       -0.397683
# 60-64_years                   -0.545473        0.058240       -0.342446
# 65-74_years                   -0.381700        0.093950       -0.067571
# 75-84_years                   -0.582381       -0.084271       -0.296038
# 85_years_or_more              -0.571554       -0.361627       -0.407843
# households                    -0.729911       -0.317245       -0.583851
# $9,999_or_less                -0.116572       -0.388772       -0.643961
# $10,000-$14,999                0.046847        0.146114       -0.389745
# $15,000-$24,999               -0.203118        0.248347       -0.476571
# $25,000-$34,999                0.142135        0.271090       -0.181622
# $35,000-$49,999               -0.310615       -0.440955       -0.043237
# $50,000-$64,999               -0.257972       -0.064276        0.171065
# $65,000-$74,999                0.320889        0.196843        0.690600
# $75,000_or_more                0.150591       -0.029666        0.374676
# median_household_income        0.069485       -0.022707        0.499312
# mean_household_income          0.078787       -0.079572        0.423384
# 5_years_or_less_fr            -0.522616       -0.406007       -0.437198
# 5-9_years_fr                  -0.525138        0.024838       -0.032157
# 10-14_years_fr                -0.389437       -0.188918       -0.205862
# 15-19_years_fr                 0.131193       -0.260218        0.335796
# 20-24_years_fr                 0.152297       -0.416228       -0.094588
# 25-34_years_fr                -0.370280       -0.239597       -0.709397
# 35-44_years_fr                -0.568389       -0.461560       -0.582744
# 45-54_years_fr                -0.387732       -0.410550       -0.455076
# 55-59_years_fr                 1.000000        0.634544        0.773211
# 60-64_years_fr                 0.634544        1.000000        0.651861
# 65-74_years_fr                 0.773211        0.651861        1.000000
# 75-84_years_fr                 0.152710        0.626584        0.488196
# 85_years_or_more_fr            0.023199       -0.148692        0.072296
#
#                          75-84_years_fr  85_years_or_more_fr
# number_of_listings            -0.167020             0.211860
# overall_capacity              -0.110876             0.262730
# overall_availability          -0.093215             0.274859
# overall_activity              -0.060280             0.333647
# zipcode                        0.259491             0.360953
# population                     0.134241             0.053662
# 5_years_or_less               -0.005557             0.083973
# 5-9_years                      0.165980             0.008702
# 10-14_years                    0.007642            -0.166572
# 15-19_years                    0.175431             0.098059
# 20-24_years                   -0.043517             0.010571
# 25-34_years                   -0.056067             0.045381
# 35-44_years                    0.030439            -0.048634
# 45-54_years                   -0.029076            -0.010886
# 55-59_years                    0.354804             0.122104
# 60-64_years                    0.434686            -0.011742
# 65-74_years                    0.630406             0.182909
# 75-84_years                    0.513568             0.225229
# 85_years_or_more               0.269010             0.617739
# households                     0.170633             0.143891
# $9,999_or_less                -0.573568             0.166776
# $10,000-$14,999               -0.073425             0.034076
# $15,000-$24,999                0.173680            -0.092590
# $25,000-$34,999                0.082405            -0.305231
# $35,000-$49,999               -0.114072            -0.168511
# $50,000-$64,999                0.085470            -0.293198
# $65,000-$74,999                0.008884            -0.103091
# $75,000_or_more                0.222479             0.399185
# median_household_income        0.080832             0.043054
# mean_household_income          0.325492             0.474210
# 5_years_or_less_fr            -0.326342             0.103140
# 5-9_years_fr                   0.473125            -0.112257
# 10-14_years_fr                -0.326757            -0.506368
# 15-19_years_fr                -0.055471             0.037729
# 20-24_years_fr                -0.416034             0.055038
# 25-34_years_fr                -0.267631             0.114661
# 35-44_years_fr                -0.218319            -0.309668
# 45-54_years_fr                -0.542748            -0.200463
# 55-59_years_fr                 0.152710             0.023199
# 60-64_years_fr                 0.626584            -0.148692
# 65-74_years_fr                 0.488196             0.072296
# 75-84_years_fr                 1.000000             0.271964
# 85_years_or_more_fr            0.271964             1.000000
#
# [43 rows x 43 columns]
# 49
#                          number_of_listings  overall_capacity  \
# number_of_listings                 1.000000          0.995744
# overall_capacity                   0.995744          1.000000
# overall_availability               0.995946          0.996872
# overall_activity                   0.985510          0.996143
# zipcode                            0.052038          0.045882
# population                         0.335604          0.312208
# 5_years_or_less                    0.164682          0.146093
# 5-9_years                          0.089945          0.086365
# 10-14_years                        0.021899          0.028384
# 15-19_years                        0.176755          0.142416
# 20-24_years                        0.349581          0.291953
# 25-34_years                        0.481783          0.449291
# 35-44_years                        0.278999          0.266792
# 45-54_years                        0.187965          0.187737
# 55-59_years                        0.260778          0.267386
# 60-64_years                        0.268016          0.276212
# 65-74_years                        0.214915          0.229919
# 75-84_years                        0.087407          0.103252
# 85_years_or_more                   0.117091          0.137622
# households                         0.437113          0.416460
# $9,999_or_less                     0.325273          0.285421
# $10,000-$14,999                    0.198911          0.157072
# $15,000-$24,999                    0.215452          0.173873
# $25,000-$34,999                    0.020721         -0.012856
# $35,000-$49,999                    0.001426         -0.025767
# $50,000-$64,999                    0.004184         -0.004683
# $65,000-$74,999                   -0.195653         -0.185479
# $75,000_or_more                   -0.176191         -0.136811
# median_household_income           -0.211539         -0.164004
# mean_household_income             -0.125651         -0.074251
# 5_years_or_less_fr                -0.147585         -0.144771
# 5-9_years_fr                      -0.286046         -0.256215
# 10-14_years_fr                    -0.320041         -0.284592
# 15-19_years_fr                    -0.083229         -0.092043
# 20-24_years_fr                     0.183959          0.134064
# 25-34_years_fr                     0.398292          0.368361
# 35-44_years_fr                    -0.028156         -0.012280
# 45-54_years_fr                    -0.253359         -0.213774
# 55-59_years_fr                    -0.129301         -0.082466
# 60-64_years_fr                    -0.075838         -0.035353
# 65-74_years_fr                    -0.154761         -0.106726
# 75-84_years_fr                    -0.185618         -0.154481
# 85_years_or_more_fr               -0.038176         -0.007508
#
#                          overall_availability  overall_activity   zipcode  \
# number_of_listings                   0.995946          0.985510  0.052038
# overall_capacity                     0.996872          0.996143  0.045882
# overall_availability                 1.000000          0.993723  0.061473
# overall_activity                     0.993723          1.000000  0.050451
# zipcode                              0.061473          0.050451  1.000000
# population                           0.354768          0.315515 -0.005879
# 5_years_or_less                      0.196856          0.157087 -0.005264
# 5-9_years                            0.128135          0.108465 -0.028437
# 10-14_years                          0.064066          0.057552 -0.079370
# 15-19_years                          0.136867          0.113035 -0.128847
# 20-24_years                          0.305376          0.253130 -0.028669
# 25-34_years                          0.499060          0.444581  0.083616
# 35-44_years                          0.314686          0.280301  0.081217
# 45-54_years                          0.231143          0.212465  0.003480
# 55-59_years                          0.305780          0.295394 -0.002181
# 60-64_years                          0.311555          0.303101  0.013712
# 65-74_years                          0.257203          0.257792 -0.084523
# 75-84_years                          0.120874          0.126406 -0.305645
# 85_years_or_more                     0.142842          0.154200 -0.128854
# households                           0.460066          0.420913  0.039335
# $9,999_or_less                       0.266939          0.240098 -0.108462
# $10,000-$14,999                      0.153868          0.114687 -0.181968
# $15,000-$24,999                      0.190774          0.142475 -0.234209
# $25,000-$34,999                      0.011402         -0.033737 -0.121962
# $35,000-$49,999                      0.004565         -0.037019 -0.214271
# $50,000-$64,999                      0.020617         -0.008106  0.050536
# $65,000-$74,999                     -0.168324         -0.169383  0.032544
# $75,000_or_more                     -0.157227         -0.108087  0.156665
# median_household_income             -0.178082         -0.122647  0.162788
# mean_household_income               -0.097206         -0.032891  0.163490
# 5_years_or_less_fr                  -0.110311         -0.123426  0.053297
# 5-9_years_fr                        -0.247500         -0.220902 -0.037914
# 10-14_years_fr                      -0.282124         -0.246106 -0.089196
# 15-19_years_fr                      -0.112049         -0.109399 -0.072868
# 20-24_years_fr                       0.125670          0.086846 -0.029278
# 25-34_years_fr                       0.390001          0.346360  0.106493
# 35-44_years_fr                       0.005543          0.009339  0.180720
# 45-54_years_fr                      -0.212581         -0.176341  0.030269
# 55-59_years_fr                      -0.087220         -0.039946 -0.009423
# 60-64_years_fr                      -0.040226          0.000357 -0.023768
# 65-74_years_fr                      -0.128060         -0.075185 -0.064374
# 75-84_years_fr                      -0.173201         -0.137391 -0.217144
# 85_years_or_more_fr                 -0.026922          0.005629 -0.045118
#
#                          population  5_years_or_less  5-9_years  10-14_years  \
# number_of_listings         0.335604         0.164682   0.089945     0.021899
# overall_capacity           0.312208         0.146093   0.086365     0.028384
# overall_availability       0.354768         0.196856   0.128135     0.064066
# overall_activity           0.315515         0.157087   0.108465     0.057552
# zipcode                   -0.005879        -0.005264  -0.028437    -0.079370
# population                 1.000000         0.909083   0.845268     0.808543
# 5_years_or_less            0.909083         1.000000   0.924430     0.859066
# 5-9_years                  0.845268         0.924430   1.000000     0.962393
# 10-14_years                0.808543         0.859066   0.962393     1.000000
# 15-19_years                0.573864         0.360227   0.355007     0.343778
# 20-24_years                0.584498         0.369053   0.277514     0.200806
# 25-34_years                0.927979         0.870363   0.735403     0.653779
# 35-44_years                0.942079         0.909951   0.860748     0.840270
# 45-54_years                0.908464         0.850537   0.838283     0.855045
# 55-59_years                0.864666         0.771483   0.740510     0.757142
# 60-64_years                0.820926         0.722706   0.645588     0.672548
# 65-74_years                0.778642         0.664714   0.645348     0.679306
# 75-84_years                0.632885         0.571036   0.529148     0.571250
# 85_years_or_more           0.486932         0.412874   0.327637     0.380434
# households                 0.957228         0.834511   0.724388     0.689208
# $9,999_or_less             0.164224        -0.019294  -0.083961    -0.170442
# $10,000-$14,999            0.168713         0.129477   0.047024    -0.088649
# $15,000-$24,999            0.448394         0.497918   0.416879     0.288879
# $25,000-$34,999            0.123687         0.255758   0.151886     0.051947
# $35,000-$49,999            0.261515         0.364047   0.278162     0.208863
# $50,000-$64,999            0.189110         0.275293   0.148011     0.130297
# $65,000-$74,999           -0.088584        -0.063460  -0.082821    -0.014842
# $75,000_or_more           -0.366378        -0.376208  -0.267493    -0.173063
# median_household_income   -0.302144        -0.296313  -0.133422    -0.015716
# mean_household_income     -0.317637        -0.345947  -0.193990    -0.078544
# 5_years_or_less_fr         0.265155         0.554453   0.498273     0.445233
# 5-9_years_fr               0.015251         0.196284   0.453515     0.454273
# 10-14_years_fr             0.019145         0.137412   0.383908     0.490283
# 15-19_years_fr            -0.157094        -0.229788  -0.217204    -0.209576
# 20-24_years_fr             0.075537        -0.098309  -0.187815    -0.240186
# 25-34_years_fr             0.236307         0.242177   0.059183    -0.029062
# 35-44_years_fr             0.146579         0.248191   0.306780     0.335535
# 45-54_years_fr            -0.179454        -0.130309  -0.016602     0.065933
# 55-59_years_fr            -0.130848        -0.124331  -0.056504     0.000476
# 60-64_years_fr            -0.130473        -0.130853  -0.135623    -0.062792
# 65-74_years_fr            -0.331000        -0.339990  -0.277698    -0.219168
# 75-84_years_fr            -0.291500        -0.260054  -0.246538    -0.207623
# 85_years_or_more_fr       -0.117048        -0.118138  -0.174610    -0.124952
#
#                          15-19_years  ...  15-19_years_fr  20-24_years_fr  \
# number_of_listings          0.176755  ...       -0.083229        0.183959
# overall_capacity            0.142416  ...       -0.092043        0.134064
# overall_availability        0.136867  ...       -0.112049        0.125670
# overall_activity            0.113035  ...       -0.109399        0.086846
# zipcode                    -0.128847  ...       -0.072868       -0.029278
# population                  0.573864  ...       -0.157094        0.075537
# 5_years_or_less             0.360227  ...       -0.229788       -0.098309
# 5-9_years                   0.355007  ...       -0.217204       -0.187815
# 10-14_years                 0.343778  ...       -0.209576       -0.240186
# 15-19_years                 1.000000  ...        0.311963        0.574361
# 20-24_years                 0.860668  ...        0.222249        0.687552
# 25-34_years                 0.399629  ...       -0.205812        0.093322
# 35-44_years                 0.338142  ...       -0.268780       -0.145648
# 45-54_years                 0.307720  ...       -0.283379       -0.219887
# 55-59_years                 0.271840  ...       -0.274661       -0.230660
# 60-64_years                 0.229200  ...       -0.280291       -0.225271
# 65-74_years                 0.222342  ...       -0.284911       -0.263866
# 75-84_years                 0.174874  ...       -0.234658       -0.230838
# 85_years_or_more            0.067509  ...       -0.233427       -0.246323
# households                  0.420727  ...       -0.229220        0.022635
# $9,999_or_less              0.711901  ...        0.735549        0.866393
# $10,000-$14,999             0.492735  ...        0.500436        0.630129
# $15,000-$24,999             0.412047  ...        0.210309        0.475765
# $25,000-$34,999             0.014612  ...       -0.023103        0.158434
# $35,000-$49,999             0.069105  ...       -0.054882        0.061725
# $50,000-$64,999            -0.136262  ...       -0.291878       -0.191062
# $65,000-$74,999            -0.281595  ...       -0.230174       -0.328587
# $75,000_or_more            -0.343326  ...        0.316200       -0.059027
# median_household_income    -0.388378  ...       -0.282188       -0.538503
# mean_household_income      -0.348828  ...       -0.241307       -0.436683
# 5_years_or_less_fr         -0.144111  ...       -0.530404       -0.529948
# 5-9_years_fr               -0.155929  ...       -0.359063       -0.604226
# 10-14_years_fr             -0.112377  ...       -0.299815       -0.596394
# 15-19_years_fr              0.311963  ...        1.000000        0.761771
# 20-24_years_fr              0.574361  ...        0.761771        1.000000
# 25-34_years_fr             -0.077190  ...       -0.454564       -0.021472
# 35-44_years_fr             -0.280080  ...       -0.674718       -0.686559
# 45-54_years_fr             -0.438007  ...       -0.596594       -0.789415
# 55-59_years_fr             -0.371832  ...       -0.505448       -0.695641
# 60-64_years_fr             -0.370728  ...       -0.481478       -0.621674
# 65-74_years_fr             -0.453865  ...       -0.459983       -0.623544
# 75-84_years_fr             -0.321592  ...       -0.249124       -0.374941
# 85_years_or_more_fr        -0.251542  ...       -0.266930       -0.340884
#
#                          25-34_years_fr  35-44_years_fr  45-54_years_fr  \
# number_of_listings             0.398292       -0.028156       -0.253359
# overall_capacity               0.368361       -0.012280       -0.213774
# overall_availability           0.390001        0.005543       -0.212581
# overall_activity               0.346360        0.009339       -0.176341
# zipcode                        0.106493        0.180720        0.030269
# population                     0.236307        0.146579       -0.179454
# 5_years_or_less                0.242177        0.248191       -0.130309
# 5-9_years                      0.059183        0.306780       -0.016602
# 10-14_years                   -0.029062        0.335535        0.065933
# 15-19_years                   -0.077190       -0.280080       -0.438007
# 20-24_years                    0.155008       -0.323988       -0.530207
# 25-34_years                    0.496103        0.101500       -0.257276
# 35-44_years                    0.221718        0.375812       -0.038763
# 45-54_years                    0.132179        0.312628        0.145319
# 55-59_years                    0.109396        0.275035        0.122090
# 60-64_years                    0.140155        0.263369        0.085159
# 65-74_years                    0.063288        0.274873        0.175446
# 75-84_years                    0.005406        0.131702        0.096443
# 85_years_or_more               0.047363        0.176049        0.124081
# households                     0.329473        0.176487       -0.119251
# $9,999_or_less                 0.106557       -0.610467       -0.705345
# $10,000-$14,999                0.126698       -0.557620       -0.622528
# $15,000-$24,999                0.355377       -0.328820       -0.663423
# $25,000-$34,999                0.247591       -0.283984       -0.256698
# $35,000-$49,999                0.388745       -0.071391       -0.363306
# $50,000-$64,999                0.404729        0.182012       -0.015924
# $65,000-$74,999                0.167477       -0.123934        0.290084
# $75,000_or_more               -0.510246        0.072765        0.203853
# median_household_income       -0.454988        0.473792        0.655135
# mean_household_income         -0.388919        0.361522        0.589047
# 5_years_or_less_fr             0.140012        0.550439        0.209611
# 5-9_years_fr                  -0.378131        0.503815        0.462528
# 10-14_years_fr                -0.489987        0.566355        0.510902
# 15-19_years_fr                -0.454564       -0.674718       -0.596594
# 20-24_years_fr                -0.021472       -0.686559       -0.789415
# 25-34_years_fr                 1.000000        0.055468       -0.209008
# 35-44_years_fr                 0.055468        1.000000        0.448000
# 45-54_years_fr                -0.209008        0.448000        1.000000
# 55-59_years_fr                -0.223872        0.328159        0.751452
# 60-64_years_fr                -0.121923        0.272236        0.559297
# 65-74_years_fr                -0.186301        0.182700        0.717782
# 75-84_years_fr                -0.179436       -0.163874        0.383647
# 85_years_or_more_fr           -0.047519        0.113908        0.265424
#
#                          55-59_years_fr  60-64_years_fr  65-74_years_fr  \
# number_of_listings            -0.129301       -0.075838       -0.154761
# overall_capacity              -0.082466       -0.035353       -0.106726
# overall_availability          -0.087220       -0.040226       -0.128060
# overall_activity              -0.039946        0.000357       -0.075185
# zipcode                       -0.009423       -0.023768       -0.064374
# population                    -0.130848       -0.130473       -0.331000
# 5_years_or_less               -0.124331       -0.130853       -0.339990
# 5-9_years                     -0.056504       -0.135623       -0.277698
# 10-14_years                    0.000476       -0.062792       -0.219168
# 15-19_years                   -0.371832       -0.370728       -0.453865
# 20-24_years                   -0.465541       -0.415327       -0.518671
# 25-34_years                   -0.214492       -0.168710       -0.387637
# 35-44_years                   -0.028831       -0.041635       -0.244762
# 45-54_years                    0.127948        0.066911       -0.086007
# 55-59_years                    0.282850        0.181301        0.006002
# 60-64_years                    0.219891        0.311770        0.033556
# 65-74_years                    0.272205        0.247771        0.188104
# 75-84_years                    0.228836        0.272930        0.185623
# 85_years_or_more               0.258537        0.261713        0.220763
# households                    -0.054148       -0.025534       -0.222921
# $9,999_or_less                -0.519678       -0.476125       -0.414413
# $10,000-$14,999               -0.448965       -0.364275       -0.347550
# $15,000-$24,999               -0.520728       -0.466576       -0.587979
# $25,000-$34,999               -0.360329       -0.178113       -0.193088
# $35,000-$49,999               -0.385136       -0.248886       -0.439286
# $50,000-$64,999               -0.084252       -0.116763       -0.205887
# $65,000-$74,999                0.210470        0.293638        0.193801
# $75,000_or_more                0.218951        0.153647        0.230593
# median_household_income        0.537240        0.428976        0.484922
# mean_household_income          0.498583        0.410208        0.481978
# 5_years_or_less_fr             0.176592        0.047848       -0.052213
# 5-9_years_fr                   0.309780        0.150417        0.173183
# 10-14_years_fr                 0.296849        0.312558        0.182623
# 15-19_years_fr                -0.505448       -0.481478       -0.459983
# 20-24_years_fr                -0.695641       -0.621674       -0.623544
# 25-34_years_fr                -0.223872       -0.121923       -0.186301
# 35-44_years_fr                 0.328159        0.272236        0.182700
# 45-54_years_fr                 0.751452        0.559297        0.717782
# 55-59_years_fr                 1.000000        0.694860        0.743553
# 60-64_years_fr                 0.694860        1.000000        0.685550
# 65-74_years_fr                 0.743553        0.685550        1.000000
# 75-84_years_fr                 0.448553        0.516066        0.722138
# 85_years_or_more_fr            0.421530        0.327078        0.501473
#
#                          75-84_years_fr  85_years_or_more_fr
# number_of_listings            -0.185618            -0.038176
# overall_capacity              -0.154481            -0.007508
# overall_availability          -0.173201            -0.026922
# overall_activity              -0.137391             0.005629
# zipcode                       -0.217144            -0.045118
# population                    -0.291500            -0.117048
# 5_years_or_less               -0.260054            -0.118138
# 5-9_years                     -0.246538            -0.174610
# 10-14_years                   -0.207623            -0.124952
# 15-19_years                   -0.321592            -0.251542
# 20-24_years                   -0.355052            -0.290035
# 25-34_years                   -0.327334            -0.154582
# 35-44_years                   -0.281106            -0.080863
# 45-54_years                   -0.177486             0.009474
# 55-59_years                   -0.091423             0.093431
# 60-64_years                   -0.029832             0.122862
# 65-74_years                    0.031691             0.209969
# 75-84_years                    0.315557             0.389734
# 85_years_or_more               0.268359             0.700551
# households                    -0.234833            -0.020075
# $9,999_or_less                -0.117439            -0.176841
# $10,000-$14,999                0.087995            -0.128918
# $15,000-$24,999               -0.168316            -0.153578
# $25,000-$34,999                0.159955            -0.117114
# $35,000-$49,999               -0.134397            -0.203901
# $50,000-$64,999               -0.138692             0.075611
# $65,000-$74,999                0.156527            -0.106105
# $75,000_or_more               -0.048207             0.086329
# median_household_income        0.049072             0.138967
# mean_household_income          0.067545             0.185241
# 5_years_or_less_fr            -0.026934             0.071340
# 5-9_years_fr                   0.134792            -0.084583
# 10-14_years_fr                 0.068848            -0.034615
# 15-19_years_fr                -0.249124            -0.266930
# 20-24_years_fr                -0.374941            -0.340884
# 25-34_years_fr                -0.179436            -0.047519
# 35-44_years_fr                -0.163874             0.113908
# 45-54_years_fr                 0.383647             0.265424
# 55-59_years_fr                 0.448553             0.421530
# 60-64_years_fr                 0.516066             0.327078
# 65-74_years_fr                 0.722138             0.501473
# 75-84_years_fr                 1.000000             0.565427
# 85_years_or_more_fr            0.565427             1.000000
#
# [43 rows x 43 columns]
# 1
#                          number_of_listings  overall_capacity  \
# number_of_listings                      NaN               NaN
# overall_capacity                        NaN               NaN
# overall_availability                    NaN               NaN
# overall_activity                        NaN               NaN
# zipcode                                 NaN               NaN
# population                              NaN               NaN
# 5_years_or_less                         NaN               NaN
# 5-9_years                               NaN               NaN
# 10-14_years                             NaN               NaN
# 15-19_years                             NaN               NaN
# 20-24_years                             NaN               NaN
# 25-34_years                             NaN               NaN
# 35-44_years                             NaN               NaN
# 45-54_years                             NaN               NaN
# 55-59_years                             NaN               NaN
# 60-64_years                             NaN               NaN
# 65-74_years                             NaN               NaN
# 75-84_years                             NaN               NaN
# 85_years_or_more                        NaN               NaN
# households                              NaN               NaN
# $9,999_or_less                          NaN               NaN
# $10,000-$14,999                         NaN               NaN
# $15,000-$24,999                         NaN               NaN
# $25,000-$34,999                         NaN               NaN
# $35,000-$49,999                         NaN               NaN
# $50,000-$64,999                         NaN               NaN
# $65,000-$74,999                         NaN               NaN
# $75,000_or_more                         NaN               NaN
# median_household_income                 NaN               NaN
# mean_household_income                   NaN               NaN
# 5_years_or_less_fr                      NaN               NaN
# 5-9_years_fr                            NaN               NaN
# 10-14_years_fr                          NaN               NaN
# 15-19_years_fr                          NaN               NaN
# 20-24_years_fr                          NaN               NaN
# 25-34_years_fr                          NaN               NaN
# 35-44_years_fr                          NaN               NaN
# 45-54_years_fr                          NaN               NaN
# 55-59_years_fr                          NaN               NaN
# 60-64_years_fr                          NaN               NaN
# 65-74_years_fr                          NaN               NaN
# 75-84_years_fr                          NaN               NaN
# 85_years_or_more_fr                     NaN               NaN
#
# ...
# overall_activity          -0.024871        -0.142311  -0.180941    -0.209362
# zipcode                   -0.000897        -0.004617   0.035403     0.076320
# population                 1.000000         0.930086   0.927778     0.929286
# 5_years_or_less            0.930086         1.000000   0.974941     0.951301
# 5-9_years                  0.927778         0.974941   1.000000     0.975290
# 10-14_years                0.929286         0.951301   0.975290     1.000000
# 15-19_years                0.904336         0.888637   0.912895     0.922431
# 20-24_years                0.884952         0.823379   0.816786     0.808227
# 25-34_years                0.905905         0.831410   0.785466     0.756663
# 35-44_years                0.971376         0.906546   0.889786     0.877672
# 45-54_years                0.965818         0.860930   0.870070     0.890626
# 55-59_years                0.927699         0.792157   0.808087     0.839014
# 60-64_years                0.889901         0.724024   0.736465     0.766164
# 65-74_years                0.818262         0.619092   0.639061     0.679280
# 75-84_years                0.730623         0.527604   0.547218     0.587967
# 85_years_or_more           0.562746         0.332805   0.338389     0.377611
# households                 0.892173         0.745840   0.712411     0.706067
# $9,999_or_less             0.023888         0.092265   0.042188     0.014418
# $10,000-$14,999            0.107673         0.193475   0.134589     0.100982
# $15,000-$24,999            0.351453         0.445261   0.394118     0.351174
# $25,000-$34,999            0.458693         0.537688   0.501675     0.467368
# $35,000-$49,999            0.458364         0.531322   0.498048     0.486214
# $50,000-$64,999            0.282640         0.292305   0.274085     0.284260
# $65,000-$74,999            0.041833        -0.032089  -0.010621     0.026359
# $75,000_or_more           -0.435084        -0.506850  -0.452966    -0.427172
# median_household_income   -0.358224        -0.417914  -0.353670    -0.324936
# mean_household_income     -0.385545        -0.445171  -0.395347    -0.375365
# 5_years_or_less_fr         0.394257         0.632494   0.568561     0.521179
# 5-9_years_fr               0.380217         0.544144   0.619201     0.573135
# 10-14_years_fr             0.213681         0.323639   0.382706     0.446119
# 15-19_years_fr             0.342307         0.378559   0.435609     0.471914
# 20-24_years_fr             0.333040         0.292424   0.273442     0.264891
# 25-34_years_fr             0.074284         0.042819  -0.052391    -0.114381
# 35-44_years_fr            -0.056107        -0.037037  -0.093039    -0.141805
# 45-54_years_fr            -0.304464        -0.358729  -0.307548    -0.259308
# 55-59_years_fr            -0.332964        -0.384323  -0.348982    -0.304784
# 60-64_years_fr            -0.343804        -0.450975  -0.421635    -0.384111
# 65-74_years_fr            -0.403040        -0.503133  -0.466134    -0.432676
# 75-84_years_fr            -0.349042        -0.436265  -0.410605    -0.385398
# 85_years_or_more_fr       -0.297832        -0.357860  -0.350737    -0.335438
#
#                          15-19_years  ...  15-19_years_fr  20-24_years_fr  \
# number_of_listings         -0.146844  ...       -0.343011        0.046495
# overall_capacity           -0.164776  ...       -0.343784        0.009433
# overall_availability       -0.147544  ...       -0.343599        0.030701
# overall_activity           -0.172449  ...       -0.344946       -0.013150
# zipcode                     0.045010  ...        0.163839       -0.103975
# population                  0.904336  ...        0.342307        0.333040
# 5_years_or_less             0.888637  ...        0.378559        0.292424
# 5-9_years                   0.912895  ...        0.435609        0.273442
# 10-14_years                 0.922431  ...        0.471914        0.264891
# 15-19_years                 1.000000  ...        0.648883        0.505042
# 20-24_years                 0.923054  ...        0.518565        0.698156
# 25-34_years                 0.726988  ...        0.111485        0.358118
# 35-44_years                 0.817683  ...        0.203871        0.254919
# 45-54_years                 0.833409  ...        0.279281        0.192700
# 55-59_years                 0.791285  ...        0.260489        0.159709
# 60-64_years                 0.729489  ...        0.197126        0.125176
# 65-74_years                 0.651684  ...        0.161380        0.075979
# 75-84_years                 0.574194  ...        0.127444        0.071313
# 85_years_or_more            0.419471  ...        0.075608        0.087360
# households                  0.677352  ...        0.063926        0.225924
# $9,999_or_less              0.093772  ...        0.082630        0.340386
# $10,000-$14,999             0.110130  ...       -0.053199        0.280637
# $15,000-$24,999             0.356476  ...        0.202392        0.400713
# $25,000-$34,999             0.457006  ...        0.297494        0.389772
# $35,000-$49,999             0.450502  ...        0.317165        0.363618
# $50,000-$64,999             0.259096  ...        0.207692        0.228766
# $65,000-$74,999            -0.007667  ...       -0.035797       -0.109455
# $75,000_or_more            -0.427916  ...       -0.250183       -0.475698
# median_household_income    -0.347857  ...       -0.173944       -0.464912
# mean_household_income      -0.379501  ...       -0.244818       -0.464020
# 5_years_or_less_fr          0.438406  ...        0.381873        0.156937
# 5-9_years_fr                0.486555  ...        0.552438        0.056374
# 10-14_years_fr              0.347152  ...        0.540615        0.033183
# 15-19_years_fr              0.648883  ...        1.000000        0.547600
# 20-24_years_fr              0.505042  ...        0.547600        1.000000
# 25-34_years_fr             -0.119467  ...       -0.455342        0.197809
# 35-44_years_fr             -0.234777  ...       -0.496836       -0.160993
# 45-54_years_fr             -0.350585  ...       -0.205295       -0.554409
# 55-59_years_fr             -0.340003  ...       -0.217080       -0.410926
# 60-64_years_fr             -0.406947  ...       -0.349985       -0.500859
# 65-74_years_fr             -0.438998  ...       -0.346913       -0.498025
# 75-84_years_fr             -0.374545  ...       -0.351969       -0.384715
# 85_years_or_more_fr        -0.301858  ...       -0.284352       -0.242165
#
#                          25-34_years_fr  35-44_years_fr  45-54_years_fr  \
# number_of_listings             0.492932        0.353226       -0.078512
# overall_capacity               0.455767        0.336511       -0.051633
# overall_availability           0.471537        0.331874       -0.057107
# overall_activity               0.426211        0.305579       -0.026660
# zipcode                       -0.300480       -0.213237        0.185149
# population                     0.074284       -0.056107       -0.304464
# 5_years_or_less                0.042819       -0.037037       -0.358729
# 5-9_years                     -0.052391       -0.093039       -0.307548
# 10-14_years                   -0.114381       -0.141805       -0.259308
# 15-19_years                   -0.119467       -0.234777       -0.350585
# 20-24_years                    0.111863       -0.149631       -0.468014
# 25-34_years                    0.432308        0.153333       -0.429864
# 35-44_years                    0.199895        0.131228       -0.309373
# 45-54_years                   -0.019193       -0.069166       -0.092533
# 55-59_years                   -0.072094       -0.128219       -0.089838
# 60-64_years                   -0.047784       -0.126001       -0.111691
# 65-74_years                   -0.096098       -0.174841       -0.064424
# 75-84_years                   -0.123020       -0.201167       -0.047744
# 85_years_or_more              -0.072482       -0.192285       -0.073743
# households                     0.287201        0.096023       -0.236208
# $9,999_or_less                 0.344388       -0.021021       -0.249618
# $10,000-$14,999                0.403692        0.138249       -0.353155
# $15,000-$24,999                0.301376        0.008723       -0.489834
# $25,000-$34,999                0.242006       -0.043245       -0.427976
# $35,000-$49,999                0.183025        0.015665       -0.460846
# $50,000-$64,999                0.179725       -0.117695       -0.175222
# $65,000-$74,999               -0.156036       -0.047907        0.219000
# $75,000_or_more               -0.379841        0.012757        0.492777
# median_household_income       -0.457299       -0.008863        0.451279
# mean_household_income         -0.377278       -0.031380        0.376090
# 5_years_or_less_fr            -0.078837        0.087488       -0.358049
# 5-9_years_fr                  -0.376283       -0.178804       -0.100670
# 10-14_years_fr                -0.528047       -0.075866       -0.044701
# 15-19_years_fr                -0.455342       -0.496836       -0.205295
# 20-24_years_fr                 0.197809       -0.160993       -0.554409
# 25-34_years_fr                 1.000000        0.513737       -0.379111
# 35-44_years_fr                 0.513737        1.000000       -0.173327
# 45-54_years_fr                -0.379111       -0.173327        1.000000
# 55-59_years_fr                -0.361072       -0.311116        0.532877
# 60-64_years_fr                -0.296352       -0.287439        0.455744
# 65-74_years_fr                -0.362607       -0.364226        0.357678
# 75-84_years_fr                -0.284978       -0.283250        0.211611
# 85_years_or_more_fr           -0.225338       -0.273389        0.037703
#
#                          55-59_years_fr  60-64_years_fr  65-74_years_fr  \
# number_of_listings            -0.106828       -0.036102       -0.016945
# overall_capacity              -0.079281       -0.006003        0.017547
# overall_availability          -0.085279       -0.010236        0.002599
# overall_activity              -0.051109        0.025292        0.045408
# zipcode                        0.266477        0.144008        0.127724
# population                    -0.332964       -0.343804       -0.403040
# 5_years_or_less               -0.384323       -0.450975       -0.503133
# 5-9_years                     -0.348982       -0.421635       -0.466134
# 10-14_years                   -0.304784       -0.384111       -0.432676
# 15-19_years                   -0.340003       -0.406947       -0.438998
# 20-24_years                   -0.417960       -0.463258       -0.492212
# 25-34_years                   -0.433475       -0.425112       -0.483949
# 35-44_years                   -0.364964       -0.374567       -0.445546
# 45-54_years                   -0.219909       -0.237871       -0.310067
# 55-59_years                   -0.079446       -0.118069       -0.212635
# 60-64_years                   -0.117467        0.037492       -0.109877
# 65-74_years                   -0.079159        0.058566        0.063791
# 75-84_years                   -0.054532        0.074246        0.075856
# 85_years_or_more              -0.033031        0.129926        0.134957
# households                    -0.289247       -0.232584       -0.292747
# $9,999_or_less                -0.174379       -0.241209       -0.318021
# $10,000-$14,999               -0.157992       -0.262115       -0.367205
# $15,000-$24,999               -0.350697       -0.437598       -0.470423
# $25,000-$34,999               -0.387588       -0.440734       -0.490968
# $35,000-$49,999               -0.450765       -0.473981       -0.510278
# $50,000-$64,999               -0.117277       -0.236865       -0.266508
# $65,000-$74,999                0.221498        0.147053        0.153275
# $75,000_or_more                0.362888        0.487749        0.566925
# median_household_income        0.307533        0.418483        0.530818
# mean_household_income          0.300245        0.440723        0.599880
# 5_years_or_less_fr            -0.504935       -0.550965       -0.582559
# 5-9_years_fr                  -0.337140       -0.408630       -0.417929
# 10-14_years_fr                -0.222827       -0.304011       -0.360600
# 15-19_years_fr                -0.217080       -0.349985       -0.346913
# 20-24_years_fr                -0.410926       -0.500859       -0.498025
# 25-34_years_fr                -0.361072       -0.296352       -0.362607
# 35-44_years_fr                -0.311116       -0.287439       -0.364226
# 45-54_years_fr                 0.532877        0.455744        0.357678
# 55-59_years_fr                 1.000000        0.634488        0.547547
# 60-64_years_fr                 0.634488        1.000000        0.697780
# 65-74_years_fr                 0.547547        0.697780        1.000000
# 75-84_years_fr                 0.352155        0.524161        0.759184
# 85_years_or_more_fr            0.243753        0.389417        0.647668
#
#                          75-84_years_fr  85_years_or_more_fr
# number_of_listings            -0.044773             0.019965
# overall_capacity              -0.016846             0.039820
# overall_availability          -0.032893             0.033905
# overall_activity               0.005977             0.061683
# zipcode                       -0.020636            -0.030931
# population                    -0.349042            -0.297832
# 5_years_or_less               -0.436265            -0.357860
# 5-9_years                     -0.410605            -0.350737
# 10-14_years                   -0.385398            -0.335438
# 15-19_years                   -0.374545            -0.301858
# 20-24_years                   -0.402500            -0.299116
# 25-34_years                   -0.421364            -0.315406
# 35-44_years                   -0.392365            -0.322823
# 45-54_years                   -0.279228            -0.269534
# 55-59_years                   -0.200884            -0.213750
# 60-64_years                   -0.126344            -0.155776
# 65-74_years                    0.002889            -0.072046
# 75-84_years                    0.206379             0.039992
# 85_years_or_more               0.221799             0.278331
# households                    -0.265124            -0.210190
# $9,999_or_less                -0.218086            -0.172151
# $10,000-$14,999               -0.217471            -0.189621
# $15,000-$24,999               -0.321855            -0.265797
# $25,000-$34,999               -0.411982            -0.320404
# $35,000-$49,999               -0.445065            -0.368336
# $50,000-$64,999               -0.263700            -0.196635
# $65,000-$74,999                0.084408             0.071308
# $75,000_or_more                0.441810             0.355844
# median_household_income        0.396966             0.305707
# mean_household_income          0.490390             0.413239
# 5_years_or_less_fr            -0.519401            -0.411240
# 5-9_years_fr                  -0.429228            -0.409472
# 10-14_years_fr                -0.367727            -0.339686
# 15-19_years_fr                -0.351969            -0.284352
# 20-24_years_fr                -0.384715            -0.242165
# 25-34_years_fr                -0.284978            -0.225338
# 35-44_years_fr                -0.283250            -0.273389
# 45-54_years_fr                 0.211611             0.037703
# 55-59_years_fr                 0.352155             0.243753
# 60-64_years_fr                 0.524161             0.389417
# 65-74_years_fr                 0.759184             0.647668
# 75-84_years_fr                 1.000000             0.733322
# 85_years_or_more_fr            0.733322             1.000000
#
# [43 rows x 43 columns]

# %% [markdown]
# # Part 3: Discussing the correlations

# %% [markdown]
# It is clear that the majority of Airbnb listings are in California (so not much point grouping by state), and trends are generally similar for each state. Quite remarkably, the demographic features that (anti)correlate most with Airbnb listings are population FRACTIONS of <5, 5-9, 10-14 and 15-19 yo, 25-34 yo etc BY AGE,  with income <15 k USD and income 50 - 75 k USD BY INCOME. Also, there is not much correlation with the number of households, meaning airbnb prices are driven mostly by other factors (e.g. venues). Almost no correlation with population, enhancing the point that airbnb is driven by venues (or might be).

# %% [markdown]
# # Part 4: Investigating the patterns in proportion of young adult population (25-44), children population (0-14), low-income households (<15k) and medium-income households (50-75 k).

# %%
df2 = pd.DataFrame()

# %%
df_new.columns
# Out:
# Index(['zipcodes', 'number_of_listings', 'overall_capacity',
#        'overall_availability', 'overall_activity', 'zipcode', 'state',
#        'population', '5_years_or_less', '5-9_years', '10-14_years',
#        '15-19_years', '20-24_years', '25-34_years', '35-44_years',
#        '45-54_years', '55-59_years', '60-64_years', '65-74_years',
#        '75-84_years', '85_years_or_more', 'households', '$9,999_or_less',
#        '$10,000-$14,999', '$15,000-$24,999', '$25,000-$34,999',
#        '$35,000-$49,999', '$50,000-$64,999', '$65,000-$74,999',
#        '$75,000_or_more', 'median_household_income', 'mean_household_income',
#        '5_years_or_less_fr', '5-9_years_fr', '10-14_years_fr',
#        '15-19_years_fr', '20-24_years_fr', '25-34_years_fr', '35-44_years_fr',
#        '45-54_years_fr', '55-59_years_fr', '60-64_years_fr', '65-74_years_fr',
#        '75-84_years_fr', '85_years_or_more_fr'],
#       dtype='object')

# %%
df2['zipcode'] = df_new['zipcode']
df2['state'] = df_new['state']
df2['number_of_listings'] = df_new['number_of_listings']
df2['overall_capacity'] = df_new['overall_capacity']
df2['overall_availability'] = df_new['overall_availability']

df2['children'] = df_new['5_years_or_less_fr'] + df_new['5-9_years_fr'] + df_new['10-14_years_fr']
df2['young_adults'] = df_new['25-34_years_fr'] + df_new['35-44_years_fr'] 

df2['low_income'] = df_new['$9,999_or_less'] + df_new['$10,000-$14,999']
df2['medium_income'] = df_new['$50,000-$64,999'] +df_new['$65,000-$74,999']

df2['median_household_income'] = df_new['median_household_income']
df2['households'] = df_new['households']

# %%
df2
# Out:
#      zipcode state  number_of_listings  overall_capacity  \
# 0      28806    NC                 239             821.0
# 1      28801    NC                 203             660.0
# 2      28803    NC                 115             446.0
# 3      28805    NC                  98             358.0
# 4      28804    NC                 121             449.0
# ..       ...   ...                 ...               ...
# 412    91361    CA                   7              15.0
# 413    91306    CA                  39             122.0
# 414    90606    CA                   3              25.0
# 415    90095    CA                   2               9.0
# 416    90602    CA                  19             102.0
#
#      overall_availability  children  young_adults  low_income  medium_income  \
# 0                    3412  0.190200      0.340500        16.8           27.0
# 1                    2590  0.132028      0.317692        25.1           19.0
# 2                    1916  0.178188      0.281308        13.5           28.3
# 3                    1433  0.152915      0.257746        13.5           28.5
# 4                    1984  0.134176      0.226018        11.3           25.9
# ..                    ...       ...           ...         ...            ...
# 412                   181  0.145984      0.181652         6.1           23.7
# 413                   817  0.175826      0.315998         9.5           32.5
# 414                    28  0.182127      0.295256         8.3           36.1
# 415                    32       NaN           NaN         NaN            NaN
# 416                   251  0.209584      0.291419        10.7           28.2
#
#      median_household_income  households
# 0                    41208.0       16570
# 1                    31359.0        6511
# 2                    47474.0       13862
# 3                    45335.0        8483
# 4                    50193.0        8257
# ..                       ...         ...
# 412                 104807.0        8539
# 413                  61529.0       14447
# 414                  64393.0        8539
# 415                      NaN           0
# 416                  48109.0        8116
#
# [417 rows x 11 columns]

# %%
correlation = df2[['number_of_listings', 'children', 'young_adults', 'low_income', 'medium_income', 'median_household_income', 'households']].corr()

plt.figure(figsize = (20, 14))

sns.heatmap(correlation,annot=True, fmt = ".2f", cmap = "coolwarm")

# %%
plt.figure(figsize = (20, 10))
sns.distplot(df2['number_of_listings'])

# %%
df_low = df2[df2['number_of_listings'] < 200]
#df_medium = df2[(df2['number_of_listings'] > 80) & (df2['number_of_listings'] < 150)]
df_high = df2[df2['number_of_listings'] >= 200]

# %%
statistics = pd.DataFrame(index = ['young_adults', 'children', 'low_income', 'medium_income', 'median_household_income', 'households'])

# %%
statistics['KS p-val'] = [ks_2samp(df_low['young_adults'], df_high['young_adults'])[1], ks_2samp(df_low['children'], df_high['children'])[1], ks_2samp(df_low['low_income'], df_high['low_income'])[1], ks_2samp(df_low['medium_income'], df_high['medium_income'])[1], ks_2samp(df_low['median_household_income'], df_high['median_household_income'])[1], ks_2samp(df_low['households'], df_high['households'])[1]]

# %%
mean_high = []
mean_low = []
stdev_high = []
stdev_low = []

# %%
plt.figure(figsize = (20, 10))
sns.distplot(df_low['young_adults'])

mean_low.append(df_low['young_adults'].mean())
stdev_low.append(df_low['young_adults'].std())
mean_high.append(df_high['young_adults'].mean())
stdev_high.append(df_high['young_adults'].std())
#sns.distplot(df_medium['young_adults'])
sns.distplot(df_high['young_adults'])
plt.legend(['Low Airbnb activity', 'High Airbnb activity'], frameon = False)

# %%
plt.figure(figsize = (20, 10))
sns.distplot(df_low['children'])

mean_low.append(df_low['children'].mean())
stdev_low.append(df_low['children'].std())
mean_high.append(df_high['children'].mean())
stdev_high.append(df_high['children'].std())
#sns.distplot(df_medium['young_adults'])
sns.distplot(df_high['children'])
plt.legend(['Low Airbnb activity', 'High Airbnb activity'], frameon = False)

# %%
plt.figure(figsize = (20, 10))
sns.distplot(df_low['low_income'])

mean_low.append(df_low['low_income'].mean())
stdev_low.append(df_low['low_income'].std())
mean_high.append(df_high['low_income'].mean())
stdev_high.append(df_high['low_income'].std())
#sns.distplot(df_medium['young_adults'])
sns.distplot(df_high['low_income'])
plt.legend(['Low Airbnb activity', 'High Airbnb activity'], frameon = False)

# %%
plt.figure(figsize = (20, 10))
sns.distplot(df_low['medium_income'])

mean_low.append(df_low['medium_income'].mean())
stdev_low.append(df_low['medium_income'].std())
mean_high.append(df_high['medium_income'].mean())
stdev_high.append(df_high['medium_income'].std())
#sns.distplot(df_medium['young_adults'])
sns.distplot(df_high['medium_income'])
plt.legend(['Low Airbnb activity', 'High Airbnb activity'], frameon = False)

# %%
plt.figure(figsize = (20, 10))
sns.distplot(df_low['median_household_income'])

mean_low.append(df_low['median_household_income'].mean())
stdev_low.append(df_low['median_household_income'].std())
mean_high.append(df_high['median_household_income'].mean())
stdev_high.append(df_high['median_household_income'].std())
#sns.distplot(df_medium['young_adults'])
sns.distplot(df_high['median_household_income'])
plt.legend(['Low Airbnb activity', 'High Airbnb activity'], frameon = False)

# %%
plt.figure(figsize = (20, 10))
sns.distplot(df_low['households'])

mean_low.append(df_low['households'].mean())
stdev_low.append(df_low['households'].std())
mean_high.append(df_high['households'].mean())
stdev_high.append(df_high['households'].std())
#sns.distplot(df_medium['young_adults'])
sns.distplot(df_high['households'])
plt.legend(['Low Airbnb activity', 'High Airbnb activity'], frameon = False)

# %%
statistics['mean_high'] = mean_high
statistics['mean_low'] = mean_low
statistics['stdev_high'] = stdev_high
statistics['stdev_low'] = stdev_low

# %%
statistics
# Out:
#                              KS p-val     mean_high      mean_low  \
# young_adults             1.443290e-15      0.370027      0.289276
# children                 3.588463e-12      0.133862      0.186460
# low_income               1.808910e-04     16.309375     11.885143
# medium_income            3.626562e-06     25.089062     28.506286
# median_household_income  8.278389e-02  58024.953125  64576.565714
# households               2.244472e-03  14061.968750  10754.195467
#
#                            stdev_high     stdev_low
# young_adults                 0.074497      0.061514
# children                     0.044008      0.049177
# low_income                   8.729874      7.785973
# medium_income                4.971159      5.863780
# median_household_income  26980.404343  27588.310315
# households                6062.308018   5934.694759

# %%
listings.columns
# Out:
# Index(['accommodates', 'amenities', 'availability_30', 'bathrooms', 'bed_type',
#        'bedrooms', 'beds', 'cancellation_policy', 'city', 'has_availability',
#        'host_id', 'id', 'instant_bookable', 'latitude', 'longitude',
#        'metropolitan', 'name', 'price', 'property_type',
#        'review_scores_checkin', 'review_scores_cleanliness',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_rating', 'review_scores_value', 'room_type', 'state',
#        'weekly_price', 'zipcode', 'overall_activity'],
#       dtype='object')

# %%
df_high
# Out:
#      zipcode state  number_of_listings  overall_capacity  \
# 0      28806    NC                 239             821.0
# 1      28801    NC                 203             660.0
# 12     78751    TX                 426            1487.0
# 14     78705    TX                 509            1922.0
# 16     78722    TX                 205             822.0
# ..       ...   ...                 ...               ...
# 331    91748    CA                 355            1202.0
# 353    90405    CA                 299             973.0
# 355    90803    CA                 224             864.0
# 356    90802    CA                 312             931.0
# 365    90265    CA                 425            2268.0
#
#      overall_availability  children  young_adults  low_income  medium_income  \
# 0                    3412  0.190200      0.340500        16.8           27.0
# 1                    2590  0.132028      0.317692        25.1           19.0
# 12                   4390  0.092999      0.465826        16.4           24.8
# 14                   4293  0.017622      0.153960        54.8           12.3
# 16                   2335  0.123751      0.481159         7.1           33.1
# ..                    ...       ...           ...         ...            ...
# 331                  7183  0.143221      0.276984         9.8           31.2
# 353                  3499  0.119972      0.337921        14.5           24.7
# 355                  2941  0.094579      0.351698         6.5           31.6
# 356                  4618  0.136075      0.392364        18.9           27.2
# 365                  7609  0.137638      0.168529         7.1           17.4
#
#      median_household_income  households
# 0                    41208.0       16570
# 1                    31359.0        6511
# 12                   45726.0        7388
# 14                   12385.0        8704
# 16                   64929.0        2973
# ..                       ...         ...
# 331                  58502.0       13476
# 353                  77948.0       14254
# 355                  75197.0       16995
# 356                  42829.0       20636
# 365                 123681.0        7206
#
# [64 rows x 11 columns]

# %%
avg_occ_by_zip = pd.read_csv("./avg_occ_rate_by_zipcode.csv")

# %%
df_high = df_high.merge(avg_occ_by_zip, how = 'left', on = 'zipcode')

# %%
correlation = df_high[['zipcode','number_of_listings', 'children', 'young_adults', 'low_income', 'medium_income', 'median_household_income', 'households', 'occupied_per']].corr()

plt.figure(figsize = (16, 12))

sns.heatmap(correlation,annot=True, fmt = ".2f", cmap = "coolwarm")
plt.savefig("corrmap2.pdf")

# %%
listings
# Out:
#        accommodates                                          amenities  \
# 0               2.0  {"Wireless Internet","Air Conditioning",Kitche...
# 1               4.0  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 2               1.0  {TV,"Wireless Internet","Air Conditioning",Kit...
# 3               6.0  {Internet,"Wireless Internet","Air Conditionin...
# 4               6.0  {Internet,"Wireless Internet","Free Parking on...
# ...             ...                                                ...
# 50316           2.0  {TV,"Cable TV","Wireless Internet","Pets live ...
# 50317           2.0  {"Wireless Internet",Kitchen,"Free parking on ...
# 50318          10.0  {TV,"Wireless Internet","Air conditioning",Kit...
# 50319           4.0  {TV,Internet,"Wireless Internet","Air conditio...
# 50320           8.0  {TV,"Wireless Internet","Air conditioning",Kit...
#
#        availability_30  bathrooms  bed_type  bedrooms  beds  \
# 0                    0        1.0  Real Bed       1.0   1.0
# 1                   17        1.0  Real Bed       1.0   2.0
# 2                   29        1.0  Real Bed       1.0   1.0
# 3                   28        2.5  Real Bed       1.0   6.0
# 4                   25        2.5  Real Bed       1.0   6.0
# ...                ...        ...       ...       ...   ...
# 50316               29        1.0  Real Bed       1.0   1.0
# 50317               29        1.0  Real Bed       1.0   1.0
# 50318               29        5.0  Real Bed       5.0   5.0
# 50319               28        1.0  Real Bed       2.0   2.0
# 50320               24        4.0  Real Bed       3.0   6.0
#
#       cancellation_policy       city  has_availability  ...  \
# 0                moderate  Asheville               NaN  ...
# 1                  strict  Asheville               NaN  ...
# 2                flexible  Asheville               NaN  ...
# 3                moderate  Asheville               NaN  ...
# 4                moderate  Asheville               NaN  ...
# ...                   ...        ...               ...  ...
# 50316            flexible   la habra               NaN  ...
# 50317              strict     malibu               NaN  ...
# 50318            flexible     malibu               NaN  ...
# 50319            moderate   la habra               NaN  ...
# 50320            flexible     malibu               NaN  ...
#
#        review_scores_cleanliness  review_scores_communication  \
# 0                            9.0                         10.0
# 1                           10.0                         10.0
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            9.0                          9.0
# ...                          ...                          ...
# 50316                        NaN                          NaN
# 50317                        NaN                          NaN
# 50318                        NaN                          NaN
# 50319                        NaN                          NaN
# 50320                        NaN                          NaN
#
#       review_scores_location  review_scores_rating  review_scores_value  \
# 0                        9.0                  96.0                 10.0
# 1                        9.0                  96.0                  9.0
# 2                        NaN                   NaN                  NaN
# 3                        NaN                   NaN                  NaN
# 4                        9.0                  93.0                 10.0
# ...                      ...                   ...                  ...
# 50316                    NaN                   NaN                  NaN
# 50317                    NaN                   NaN                  NaN
# 50318                    NaN                   NaN                  NaN
# 50319                    NaN                   NaN                  NaN
# 50320                    NaN                   NaN                  NaN
#
#              room_type state weekly_price  zipcode  overall_activity
# 0      Entire home/apt    NC      $650.00  28806.0               0.0
# 1      Entire home/apt    NC          NaN  28806.0              68.0
# 2         Private room    NC          NaN  28806.0              29.0
# 3          Shared room    NC          NaN  28806.0             168.0
# 4          Shared room    NC          NaN  28806.0             150.0
# ...                ...   ...          ...      ...               ...
# 50316     Private room    CA          NaN    90631              58.0
# 50317     Private room    CA          NaN    90265              58.0
# 50318  Entire home/apt    CA          NaN    90265             290.0
# 50319     Private room    CA          NaN    90631             112.0
# 50320  Entire home/apt    CA          NaN    90265             192.0
#
# [50321 rows x 30 columns]

# %%
clean_zipcodes = [clean(i) for i in listings['zipcode']]

# %%
listings['clean_zipcodes'] = clean_zipcodes

# %%
listings
# Out:
#        accommodates                                          amenities  \
# 0               2.0  {"Wireless Internet","Air Conditioning",Kitche...
# 1               4.0  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 2               1.0  {TV,"Wireless Internet","Air Conditioning",Kit...
# 3               6.0  {Internet,"Wireless Internet","Air Conditionin...
# 4               6.0  {Internet,"Wireless Internet","Free Parking on...
# ...             ...                                                ...
# 50316           2.0  {TV,"Cable TV","Wireless Internet","Pets live ...
# 50317           2.0  {"Wireless Internet",Kitchen,"Free parking on ...
# 50318          10.0  {TV,"Wireless Internet","Air conditioning",Kit...
# 50319           4.0  {TV,Internet,"Wireless Internet","Air conditio...
# 50320           8.0  {TV,"Wireless Internet","Air conditioning",Kit...
#
#        availability_30  bathrooms  bed_type  bedrooms  beds  \
# 0                    0        1.0  Real Bed       1.0   1.0
# 1                   17        1.0  Real Bed       1.0   2.0
# 2                   29        1.0  Real Bed       1.0   1.0
# 3                   28        2.5  Real Bed       1.0   6.0
# 4                   25        2.5  Real Bed       1.0   6.0
# ...                ...        ...       ...       ...   ...
# 50316               29        1.0  Real Bed       1.0   1.0
# 50317               29        1.0  Real Bed       1.0   1.0
# 50318               29        5.0  Real Bed       5.0   5.0
# 50319               28        1.0  Real Bed       2.0   2.0
# 50320               24        4.0  Real Bed       3.0   6.0
#
#       cancellation_policy       city  has_availability  ...  \
# 0                moderate  Asheville               NaN  ...
# 1                  strict  Asheville               NaN  ...
# 2                flexible  Asheville               NaN  ...
# 3                moderate  Asheville               NaN  ...
# 4                moderate  Asheville               NaN  ...
# ...                   ...        ...               ...  ...
# 50316            flexible   la habra               NaN  ...
# 50317              strict     malibu               NaN  ...
# 50318            flexible     malibu               NaN  ...
# 50319            moderate   la habra               NaN  ...
# 50320            flexible     malibu               NaN  ...
#
#        review_scores_communication  review_scores_location  \
# 0                             10.0                     9.0
# 1                             10.0                     9.0
# 2                              NaN                     NaN
# 3                              NaN                     NaN
# 4                              9.0                     9.0
# ...                            ...                     ...
# 50316                          NaN                     NaN
# 50317                          NaN                     NaN
# 50318                          NaN                     NaN
# 50319                          NaN                     NaN
# 50320                          NaN                     NaN
#
#       review_scores_rating  review_scores_value        room_type state  \
# 0                     96.0                 10.0  Entire home/apt    NC
# 1                     96.0                  9.0  Entire home/apt    NC
# 2                      NaN                  NaN     Private room    NC
# 3                      NaN                  NaN      Shared room    NC
# 4                     93.0                 10.0      Shared room    NC
# ...                    ...                  ...              ...   ...
# 50316                  NaN                  NaN     Private room    CA
# 50317                  NaN                  NaN     Private room    CA
# 50318                  NaN                  NaN  Entire home/apt    CA
# 50319                  NaN                  NaN     Private room    CA
# 50320                  NaN                  NaN  Entire home/apt    CA
#
#       weekly_price  zipcode overall_activity  clean_zipcodes
# 0          $650.00  28806.0              0.0         28806.0
# 1              NaN  28806.0             68.0         28806.0
# 2              NaN  28806.0             29.0         28806.0
# 3              NaN  28806.0            168.0         28806.0
# 4              NaN  28806.0            150.0         28806.0
# ...            ...      ...              ...             ...
# 50316          NaN    90631             58.0         90631.0
# 50317          NaN    90265             58.0         90265.0
# 50318          NaN    90265            290.0         90265.0
# 50319          NaN    90631            112.0         90631.0
# 50320          NaN    90265            192.0         90265.0
#
# [50321 rows x 31 columns]

# %%
def in_high_activity_areas(zipcode):
    return (zipcode in list(df_high['zipcode']))

# %%
in_high_activity_areas(28806.0)
# Out:
# True

# %%
airbnbs_to_compare = pd.DataFrame(columns = listings.columns)

for row in listings.index:
    if in_high_activity_areas(listings.loc[row]['clean_zipcodes']):
        airbnbs_to_compare = airbnbs_to_compare.append(listings.loc[row])

# %%
airbnbs_to_compare
# Out:
#        accommodates                                          amenities  \
# 0               2.0  {"Wireless Internet","Air Conditioning",Kitche...
# 1               4.0  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 2               1.0  {TV,"Wireless Internet","Air Conditioning",Kit...
# 3               6.0  {Internet,"Wireless Internet","Air Conditionin...
# 4               6.0  {Internet,"Wireless Internet","Free Parking on...
# ...             ...                                                ...
# 50313           4.0  {TV,"Cable TV",Internet,"Wireless Internet","W...
# 50314           6.0  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 50317           2.0  {"Wireless Internet",Kitchen,"Free parking on ...
# 50318          10.0  {TV,"Wireless Internet","Air conditioning",Kit...
# 50320           8.0  {TV,"Wireless Internet","Air conditioning",Kit...
#
#       availability_30  bathrooms  bed_type  bedrooms  beds  \
# 0                   0        1.0  Real Bed       1.0   1.0
# 1                  17        1.0  Real Bed       1.0   2.0
# 2                  29        1.0  Real Bed       1.0   1.0
# 3                  28        2.5  Real Bed       1.0   6.0
# 4                  25        2.5  Real Bed       1.0   6.0
# ...               ...        ...       ...       ...   ...
# 50313               5        1.0  Real Bed       1.0   2.0
# 50314              24        2.0  Real Bed       3.0   3.0
# 50317              29        1.0  Real Bed       1.0   1.0
# 50318              29        5.0  Real Bed       5.0   5.0
# 50320              24        4.0  Real Bed       3.0   6.0
#
#       cancellation_policy       city  has_availability  ...  \
# 0                moderate  Asheville               NaN  ...
# 1                  strict  Asheville               NaN  ...
# 2                flexible  Asheville               NaN  ...
# 3                moderate  Asheville               NaN  ...
# 4                moderate  Asheville               NaN  ...
# ...                   ...        ...               ...  ...
# 50313            flexible     malibu               NaN  ...
# 50314            moderate     malibu               NaN  ...
# 50317              strict     malibu               NaN  ...
# 50318            flexible     malibu               NaN  ...
# 50320            flexible     malibu               NaN  ...
#
#       review_scores_communication review_scores_location review_scores_rating  \
# 0                            10.0                    9.0                 96.0
# 1                            10.0                    9.0                 96.0
# 2                             NaN                    NaN                  NaN
# 3                             NaN                    NaN                  NaN
# 4                             9.0                    9.0                 93.0
# ...                           ...                    ...                  ...
# 50313                         NaN                    NaN                  NaN
# 50314                         NaN                    NaN                  NaN
# 50317                         NaN                    NaN                  NaN
# 50318                         NaN                    NaN                  NaN
# 50320                         NaN                    NaN                  NaN
#
#        review_scores_value        room_type state weekly_price  zipcode  \
# 0                     10.0  Entire home/apt    NC      $650.00  28806.0
# 1                      9.0  Entire home/apt    NC          NaN  28806.0
# 2                      NaN     Private room    NC          NaN  28806.0
# 3                      NaN      Shared room    NC          NaN  28806.0
# 4                     10.0      Shared room    NC          NaN  28806.0
# ...                    ...              ...   ...          ...      ...
# 50313                  NaN  Entire home/apt    CA          NaN    90265
# 50314                  NaN  Entire home/apt    CA          NaN    90265
# 50317                  NaN     Private room    CA          NaN    90265
# 50318                  NaN  Entire home/apt    CA          NaN    90265
# 50320                  NaN  Entire home/apt    CA          NaN    90265
#
#       overall_activity  clean_zipcodes
# 0                  0.0         28806.0
# 1                 68.0         28806.0
# 2                 29.0         28806.0
# 3                168.0         28806.0
# 4                150.0         28806.0
# ...                ...             ...
# 50313             20.0         90265.0
# 50314            144.0         90265.0
# 50317             58.0         90265.0
# 50318            290.0         90265.0
# 50320            192.0         90265.0
#
# [32367 rows x 31 columns]

# %%
airbnbs_to_compare.to_csv("C:/Users/TeamKnowHow/Documents/Summer Invitational Datathon/airbnbs_to_compare.csv")

# %%
venues_w_zip = pd.read_csv("./venues_w_zip.csv")

# %%
places = {}

for zipcode in df2['zipcode'].unique():
    places[zipcode] = 0
    
for index in venues_w_zip.index:
    if clean(venues_w_zip.loc[index]['zipcodes']) in places.keys():
        places[clean(venues_w_zip.loc[index]['zipcodes'])] += 1

# %%
df2['no_of_venues'] = df2['zipcode'].apply(lambda z: places[z])
df2
# Out:
#      zipcode state  number_of_listings  overall_capacity  \
# 0      28806    NC                 239             821.0
# 1      28801    NC                 203             660.0
# 2      28803    NC                 115             446.0
# 3      28805    NC                  98             358.0
# 4      28804    NC                 121             449.0
# ..       ...   ...                 ...               ...
# 412    91361    CA                   7              15.0
# 413    91306    CA                  39             122.0
# 414    90606    CA                   3              25.0
# 415    90095    CA                   2               9.0
# 416    90602    CA                  19             102.0
#
#      overall_availability  children  young_adults  low_income  medium_income  \
# 0                    3412  0.190200      0.340500        16.8           27.0
# 1                    2590  0.132028      0.317692        25.1           19.0
# 2                    1916  0.178188      0.281308        13.5           28.3
# 3                    1433  0.152915      0.257746        13.5           28.5
# 4                    1984  0.134176      0.226018        11.3           25.9
# ..                    ...       ...           ...         ...            ...
# 412                   181  0.145984      0.181652         6.1           23.7
# 413                   817  0.175826      0.315998         9.5           32.5
# 414                    28  0.182127      0.295256         8.3           36.1
# 415                    32       NaN           NaN         NaN            NaN
# 416                   251  0.209584      0.291419        10.7           28.2
#
#      median_household_income  households  no_of_venues
# 0                    41208.0       16570           915
# 1                    31359.0        6511          1152
# 2                    47474.0       13862           863
# 3                    45335.0        8483           449
# 4                    50193.0        8257           427
# ..                       ...         ...           ...
# 412                 104807.0        8539             0
# 413                  61529.0       14447             0
# 414                  64393.0        8539             8
# 415                      NaN           0           146
# 416                  48109.0        8116             0
#
# [417 rows x 12 columns]

# %%
correlation = df2[['number_of_listings', 'children', 'young_adults', 'low_income', 'medium_income', 'median_household_income', 'households', 'no_of_venues']].corr()

plt.figure(figsize = (20, 14))

sns.heatmap(correlation,annot=True, fmt = ".2f", cmap = "coolwarm")

# %% [markdown]
# Trying simple linear regression

# %%
from sklearn.linear_model import LinearRegression
import copy

lr = LinearRegression()

train = copy.deepcopy(df2[['children', 'young_adults', 'low_income', 'medium_income', 'number_of_listings']])

train = train.dropna()

X = train[['children', 'young_adults', 'low_income', 'medium_income']]
y = train['number_of_listings']

lr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.score(X, y)

# R^2 score of linear regression
# generally speaking, 1 is perfect, 0 is if we predict constant mean value
# Out:
# 0.3159672468753161

# %%
lr.coef_
# Out:
# array([-1.04947693e+03,  1.30775687e+03, -4.07749799e-01, -8.32120704e+00])

# %% [markdown]
# First 2 coeff are of the opposite sign - that is fine, since the corresponding variables are negatively correlated. Mostly learns information from proportion of young adults and children.

# %%
# !jupyter nbconvert --to html Notebook1.ipynb
# Out:
# [NbConvertApp] Converting notebook Notebook1.ipynb to html
# [NbConvertApp] Writing 885420 bytes to Notebook1.html
